# %% [markdown]
# **Notebook link** : https://colab.research.google.com/drive/1UQNGoYC-2Gkmqr79zYEMe--1DBVFPMdy?usp=sharing

# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
import pandas as pd
from matplotlib import pyplot as plt
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch import nn
from torchinfo import summary
from tqdm.notebook import tqdm

import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio

import yfinance as yf
from itertools import product
import numpy as np

# %%
start = "2004-08-19"
interval = "1d"

gspc = yf.Ticker("^GSPC")
gspc_data = gspc.history(period="max", interval=interval, start=start)
gspc_data = gspc_data[["Open", "High", "Low", "Close", "Volume"]]

spy = yf.Ticker("SPY")
spy_data = spy.history(period="max", interval=interval, start=start)
spy_data = spy_data[["Open", "High", "Low", "Close", "Volume"]]
spy_data = spy_data.rename(columns={"Open": "spy_open", "High": "spy_high", "Low": "spy_low", "Close": "spy_close", "Volume": "spy_volume"})

goog = yf.Ticker("GOOG")
goog_data = goog.history(period="max", interval=interval, start=start)
goog_data = goog_data[["Open", "High", "Low", "Close", "Volume"]]
goog_data = goog_data.rename(columns={"Open": "goog_open", "High": "goog_high", "Low": "goog_low", "Close": "goog_close", "Volume": "goog_volume"})

aapl = yf.Ticker("AAPL")
aapl_data = aapl.history(period="max", interval=interval, start=start)
aapl_data = aapl_data[["Open", "High", "Low", "Close", "Volume"]]
aapl_data = aapl_data.rename(columns={"Open": "aapl_open", "High": "aapl_high", "Low": "aapl_low", "Close": "aapl_close", "Volume": "aapl_volume"})

amzn = yf.Ticker("AMZN")
amzn_data = amzn.history(period="max", interval=interval, start=start)
amzn_data = amzn_data[["Open", "High", "Low", "Close", "Volume"]]
amzn_data = amzn_data.rename(columns={"Open": "amzn_open", "High": "amzn_high", "Low": "amzn_low", "Close": "amzn_close", "Volume": "amzn_volume"})
amzn_data = amzn_data.dropna()

msft = yf.Ticker("MSFT")
msft_data = msft.history(period="max", interval=interval, start=start)
msft_data = msft_data[["Open", "High", "Low", "Close", "Volume"]]
msft_data = msft_data.rename(columns={"Open": "msft_open", "High": "msft_high", "Low": "msft_low", "Close": "msft_close", "Volume": "msft_volume"})
msft_data = msft_data.dropna()

df = pd.concat([gspc_data, spy_data, goog_data, aapl_data, amzn_data, msft_data], axis=1)
df = df.dropna()
df
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2004-08-19 00:00:00-04:00  1095.170044  1095.170044  1086.280029  1091.229980
# 2004-08-20 00:00:00-04:00  1091.229980  1100.260010  1089.569946  1098.349976
# 2004-08-23 00:00:00-04:00  1098.349976  1101.400024  1094.729980  1095.680054
# 2004-08-24 00:00:00-04:00  1095.680054  1100.939941  1092.819946  1096.189941
# 2004-08-25 00:00:00-04:00  1096.189941  1106.290039  1093.239990  1104.959961
# ...                                ...          ...          ...          ...
# 2024-07-31 00:00:00-04:00  5505.589844  5551.509766  5493.750000  5522.299805
# 2024-08-01 00:00:00-04:00  5537.839844  5566.160156  5410.419922  5446.680176
# 2024-08-02 00:00:00-04:00  5376.629883  5383.890137  5302.029785  5346.560059
# 2024-08-05 00:00:00-04:00  5151.140137  5250.890137  5119.259766  5186.330078
# 2024-08-06 00:00:00-04:00  5206.419922  5312.339844  5193.560059  5240.029785
#
#                                Volume    spy_open    spy_high     spy_low  \
# Date
# 2004-08-19 00:00:00-04:00  1249400000   74.958680   75.102030   74.528630
# 2004-08-20 00:00:00-04:00  1199900000   74.822156   75.518428   74.753895
# 2004-08-23 00:00:00-04:00  1021900000   75.463821   75.613993   75.122510
# 2004-08-24 00:00:00-04:00  1092500000   75.525277   75.586716   74.986005
# 2004-08-25 00:00:00-04:00  1192200000   75.313640   75.955301   75.020112
# ...                               ...         ...         ...         ...
# 2024-07-31 00:00:00-04:00  4546910000  548.979980  553.500000  547.580017
# 2024-08-01 00:00:00-04:00  4703620000  552.570007  554.869995  539.429993
# 2024-08-02 00:00:00-04:00  5156450000  535.750000  536.989990  528.599976
# 2024-08-05 00:00:00-04:00  5333250000  511.640015  523.580017  510.269989
# 2024-08-06 00:00:00-04:00  4690190000  519.219971  529.750000  517.869995
#
#                             spy_close   spy_volume  ...   amzn_open  \
# Date                                                ...
# 2004-08-19 00:00:00-04:00   74.890419   39881600.0  ...    2.013000
# 2004-08-20 00:00:00-04:00   75.416039   44870900.0  ...    1.923000
# 2004-08-23 00:00:00-04:00   75.224899   33745100.0  ...    1.994500
# 2004-08-24 00:00:00-04:00   75.327316   30453100.0  ...    1.986000
# 2004-08-25 00:00:00-04:00   75.839256   38551400.0  ...    1.953000
# ...                               ...          ...  ...         ...
# 2024-07-31 00:00:00-04:00  550.809998   65663400.0  ...  185.050003
# 2024-08-01 00:00:00-04:00  543.010010   76428700.0  ...  189.289993
# 2024-08-02 00:00:00-04:00  532.900024   82789100.0  ...  166.750000
# 2024-08-05 00:00:00-04:00  517.380005  146267400.0  ...  154.210007
# 2024-08-06 00:00:00-04:00  522.150024   84646600.0  ...  161.710007
#
#                             amzn_high    amzn_low  amzn_close  amzn_volume  \
# Date
# 2004-08-19 00:00:00-04:00    2.024000    1.817500    1.931500    253922000
# 2004-08-20 00:00:00-04:00    1.995500    1.905500    1.975500    135816000
# 2004-08-23 00:00:00-04:00    2.000000    1.955500    1.972500    110652000
# 2004-08-24 00:00:00-04:00    1.996500    1.916000    1.952500    152808000
# 2004-08-25 00:00:00-04:00    2.024500    1.908000    2.015000    145096000
# ...                               ...         ...         ...          ...
# 2024-07-31 00:00:00-04:00  187.940002  184.460007  186.979996     41667300
# 2024-08-01 00:00:00-04:00  190.600006  181.869995  184.070007     70435600
# 2024-08-02 00:00:00-04:00  168.770004  160.550003  167.899994    141448400
# 2024-08-05 00:00:00-04:00  162.960007  151.610001  161.020004     83149400
# 2024-08-06 00:00:00-04:00  165.080002  158.539993  161.929993     59858500
#
#                             msft_open   msft_high    msft_low  msft_close  \
# Date
# 2004-08-19 00:00:00-04:00   17.043645   17.105962   16.831767   16.900316
# 2004-08-20 00:00:00-04:00   16.906544   17.056105   16.850460   16.950167
# 2004-08-23 00:00:00-04:00   17.043920   17.081420   16.950169   17.025169
# 2004-08-24 00:00:00-04:00   17.125170   17.162670   16.931419   17.025169
# 2004-08-25 00:00:00-04:00   17.006418   17.293921   16.987668   17.218920
# ...                               ...         ...         ...         ...
# 2024-07-31 00:00:00-04:00  420.500000  421.779999  412.209991  418.350006
# 2024-08-01 00:00:00-04:00  420.790009  427.459991  413.089996  417.109985
# 2024-08-02 00:00:00-04:00  412.489990  415.000000  404.339996  408.489990
# 2024-08-05 00:00:00-04:00  389.170013  401.040009  385.579987  395.149994
# 2024-08-06 00:00:00-04:00  400.000000  405.670013  398.500000  399.609985
#
#                            msft_volume
# Date
# 2004-08-19 00:00:00-04:00     46293000
# 2004-08-20 00:00:00-04:00     46494800
# 2004-08-23 00:00:00-04:00     39572200
# 2004-08-24 00:00:00-04:00     40835300
# 2004-08-25 00:00:00-04:00     53512700
# ...                                ...
# 2024-07-31 00:00:00-04:00     42891400
# 2024-08-01 00:00:00-04:00     30296400
# 2024-08-02 00:00:00-04:00     29437900
# 2024-08-05 00:00:00-04:00     40709200
# 2024-08-06 00:00:00-04:00     24896800
#
# [5025 rows x 30 columns]

# %%
target_col = "Close"
features = list(df.columns.difference([target_col]))

forecast_lead = 1
target = f"{target_col}_lead{forecast_lead}"

df[target] = df[target_col].shift(-forecast_lead)
df = df.iloc[:-forecast_lead]
df
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2004-08-19 00:00:00-04:00  1095.170044  1095.170044  1086.280029  1091.229980
# 2004-08-20 00:00:00-04:00  1091.229980  1100.260010  1089.569946  1098.349976
# 2004-08-23 00:00:00-04:00  1098.349976  1101.400024  1094.729980  1095.680054
# 2004-08-24 00:00:00-04:00  1095.680054  1100.939941  1092.819946  1096.189941
# 2004-08-25 00:00:00-04:00  1096.189941  1106.290039  1093.239990  1104.959961
# ...                                ...          ...          ...          ...
# 2024-07-30 00:00:00-04:00  5478.729980  5489.459961  5401.700195  5436.439941
# 2024-07-31 00:00:00-04:00  5505.589844  5551.509766  5493.750000  5522.299805
# 2024-08-01 00:00:00-04:00  5537.839844  5566.160156  5410.419922  5446.680176
# 2024-08-02 00:00:00-04:00  5376.629883  5383.890137  5302.029785  5346.560059
# 2024-08-05 00:00:00-04:00  5151.140137  5250.890137  5119.259766  5186.330078
#
#                                Volume    spy_open    spy_high     spy_low  \
# Date
# 2004-08-19 00:00:00-04:00  1249400000   74.958680   75.102030   74.528630
# 2004-08-20 00:00:00-04:00  1199900000   74.822156   75.518428   74.753895
# 2004-08-23 00:00:00-04:00  1021900000   75.463821   75.613993   75.122510
# 2004-08-24 00:00:00-04:00  1092500000   75.525277   75.586716   74.986005
# 2004-08-25 00:00:00-04:00  1192200000   75.313640   75.955301   75.020112
# ...                               ...         ...         ...         ...
# 2024-07-30 00:00:00-04:00  3777740000  546.260010  547.340027  538.520020
# 2024-07-31 00:00:00-04:00  4546910000  548.979980  553.500000  547.580017
# 2024-08-01 00:00:00-04:00  4703620000  552.570007  554.869995  539.429993
# 2024-08-02 00:00:00-04:00  5156450000  535.750000  536.989990  528.599976
# 2024-08-05 00:00:00-04:00  5333250000  511.640015  523.580017  510.269989
#
#                             spy_close   spy_volume  ...   amzn_high  \
# Date                                                ...
# 2004-08-19 00:00:00-04:00   74.890419   39881600.0  ...    2.024000
# 2004-08-20 00:00:00-04:00   75.416039   44870900.0  ...    1.995500
# 2004-08-23 00:00:00-04:00   75.224899   33745100.0  ...    2.000000
# 2004-08-24 00:00:00-04:00   75.327316   30453100.0  ...    1.996500
# 2004-08-25 00:00:00-04:00   75.839256   38551400.0  ...    2.024500
# ...                               ...          ...  ...         ...
# 2024-07-30 00:00:00-04:00  542.000000   46853600.0  ...  185.860001
# 2024-07-31 00:00:00-04:00  550.809998   65663400.0  ...  187.940002
# 2024-08-01 00:00:00-04:00  543.010010   76428700.0  ...  190.600006
# 2024-08-02 00:00:00-04:00  532.900024   82789100.0  ...  168.770004
# 2024-08-05 00:00:00-04:00  517.380005  146267400.0  ...  162.960007
#
#                              amzn_low  amzn_close  amzn_volume   msft_open  \
# Date
# 2004-08-19 00:00:00-04:00    1.817500    1.931500    253922000   17.043645
# 2004-08-20 00:00:00-04:00    1.905500    1.975500    135816000   16.906544
# 2004-08-23 00:00:00-04:00    1.955500    1.972500    110652000   17.043920
# 2004-08-24 00:00:00-04:00    1.916000    1.952500    152808000   17.125170
# 2004-08-25 00:00:00-04:00    1.908000    2.015000    145096000   17.006418
# ...                               ...         ...          ...         ...
# 2024-07-30 00:00:00-04:00  179.380005  181.710007     39508600  427.720001
# 2024-07-31 00:00:00-04:00  184.460007  186.979996     41667300  420.500000
# 2024-08-01 00:00:00-04:00  181.869995  184.070007     70435600  420.790009
# 2024-08-02 00:00:00-04:00  160.550003  167.899994    141448400  412.489990
# 2024-08-05 00:00:00-04:00  151.610001  161.020004     83149400  389.170013
#
#                             msft_high    msft_low  msft_close  msft_volume  \
# Date
# 2004-08-19 00:00:00-04:00   17.105962   16.831767   16.900316     46293000
# 2004-08-20 00:00:00-04:00   17.056105   16.850460   16.950167     46494800
# 2004-08-23 00:00:00-04:00   17.081420   16.950169   17.025169     39572200
# 2004-08-24 00:00:00-04:00   17.162670   16.931419   17.025169     40835300
# 2004-08-25 00:00:00-04:00   17.293921   16.987668   17.218920     53512700
# ...                               ...         ...         ...          ...
# 2024-07-30 00:00:00-04:00  429.049988  417.359985  422.920013     32687600
# 2024-07-31 00:00:00-04:00  421.779999  412.209991  418.350006     42891400
# 2024-08-01 00:00:00-04:00  427.459991  413.089996  417.109985     30296400
# 2024-08-02 00:00:00-04:00  415.000000  404.339996  408.489990     29437900
# 2024-08-05 00:00:00-04:00  401.040009  385.579987  395.149994     40709200
#
#                            Close_lead1
# Date
# 2004-08-19 00:00:00-04:00  1098.349976
# 2004-08-20 00:00:00-04:00  1095.680054
# 2004-08-23 00:00:00-04:00  1096.189941
# 2004-08-24 00:00:00-04:00  1104.959961
# 2004-08-25 00:00:00-04:00  1105.089966
# ...                                ...
# 2024-07-30 00:00:00-04:00  5522.299805
# 2024-07-31 00:00:00-04:00  5446.680176
# 2024-08-01 00:00:00-04:00  5346.560059
# 2024-08-02 00:00:00-04:00  5186.330078
# 2024-08-05 00:00:00-04:00  5240.029785
#
# [5024 rows x 31 columns]

# %%
df[target].plot(figsize=(20, 7))
# Out:
# <Axes: xlabel='Date'>

# %%
df["volatility"] = df["High"] - df["Low"]

df["ema_5"] = df["Close"].ewm(span=5, adjust=False).mean()
df["ema_10"] = df["Close"].ewm(span=10, adjust=False).mean()
df["ema_20"] = df["Close"].ewm(span=20, adjust=False).mean()
df["ema_50"] = df["Close"].ewm(span=50, adjust=False).mean()
df["ema_100"] = df["Close"].ewm(span=100, adjust=False).mean()
# Out:
# <ipython-input-6-fe8622e2aa54>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["volatility"] = df["High"] - df["Low"]
# <ipython-input-6-fe8622e2aa54>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ema_5"] = df["Close"].ewm(span=5, adjust=False).mean()
# <ipython-input-6-fe8622e2aa54>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ema_10"] = df["Close"].ewm(span=10, adjust=False).mean()
# <ipython-input-6-fe8622e2aa54>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ema_20"] = df["Close"].ewm(span=20, adjust=False).mean()
# <ipython-input-6-fe8622e2aa54>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ema_50"] = df["Close"].ewm(span=50, adjust=False).mean()
# <ipython-input-6-fe8622e2aa54>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ema_100"] = df["Close"].ewm(span=100, adjust=False).mean()

# %%
val_start = "2020-05-01"
test_start = "2022-05-01"
end = "2024-05-01"

df_train = df.loc[:val_start].copy()
df_val = df.loc[val_start:test_start].copy()
df_test = df.loc[test_start:end].copy()

# %% [markdown]
# # **Normalization data**

# %%
target_mean = df_train[target].mean()
target_stdev = df_train[target].std()

for c in df_train.columns:
    mean = df_train[c].mean()
    stdev = df_train[c].std()

    df_train[c] = (df_train[c] - mean) / stdev
    df_val[c] = (df_val[c] - mean) / stdev
    df_test[c] = (df_test[c] - mean) / stdev
df_train.head()
# Out:
#                                Open      High       Low     Close    Volume  \
# Date
# 2004-08-19 00:00:00-04:00 -1.018745 -1.031223 -1.019979 -1.025609 -1.896172
# 2004-08-20 00:00:00-04:00 -1.025049 -1.023099 -1.014699 -1.014217 -1.934921
# 2004-08-23 00:00:00-04:00 -1.013657 -1.021279 -1.006418 -1.018489 -2.074264
# 2004-08-24 00:00:00-04:00 -1.017929 -1.022014 -1.009483 -1.017673 -2.018997
# 2004-08-25 00:00:00-04:00 -1.017113 -1.013475 -1.008809 -1.003641 -1.940949
#
#                            spy_open  spy_high   spy_low  spy_close  \
# Date
# 2004-08-19 00:00:00-04:00 -1.060413 -1.066181 -1.058256  -1.061513
# 2004-08-20 00:00:00-04:00 -1.062526 -1.059761 -1.054756  -1.053380
# 2004-08-23 00:00:00-04:00 -1.052595 -1.058287 -1.049028  -1.056337
# 2004-08-24 00:00:00-04:00 -1.051644 -1.058708 -1.051149  -1.054752
# 2004-08-25 00:00:00-04:00 -1.054919 -1.053025 -1.050619  -1.046831
#
#                            spy_volume  ...  msft_low  msft_close  msft_volume  \
# Date                                   ...
# 2004-08-19 00:00:00-04:00   -0.998557  ... -0.706717   -0.708534    -0.120300
# 2004-08-20 00:00:00-04:00   -0.947837  ... -0.706183   -0.707125    -0.113551
# 2004-08-23 00:00:00-04:00   -1.060939  ... -0.703332   -0.705005    -0.345067
# 2004-08-24 00:00:00-04:00   -1.094404  ... -0.703868   -0.705005    -0.302824
# 2004-08-25 00:00:00-04:00   -1.012079  ... -0.702260   -0.699527     0.121152
#
#                            Close_lead1  volatility     ema_5    ema_10  \
# Date
# 2004-08-19 00:00:00-04:00    -1.014656   -0.636731 -1.025344 -1.024854
# 2004-08-20 00:00:00-04:00    -1.018927   -0.527948 -1.021542 -1.022778
# 2004-08-23 00:00:00-04:00    -1.018111   -0.770892 -1.020434 -1.021858
# 2004-08-24 00:00:00-04:00    -1.004083   -0.683266 -1.019422 -1.020956
# 2004-08-25 00:00:00-04:00    -1.003875   -0.385327 -1.014065 -1.017661
#
#                              ema_20    ema_50   ema_100
# Date
# 2004-08-19 00:00:00-04:00 -1.023720 -1.020204 -1.015375
# 2004-08-20 00:00:00-04:00 -1.022630 -1.019752 -1.015143
# 2004-08-23 00:00:00-04:00 -1.022052 -1.019487 -1.015003
# 2004-08-24 00:00:00-04:00 -1.021452 -1.019201 -1.014849
# 2004-08-25 00:00:00-04:00 -1.019566 -1.018368 -1.014413
#
# [5 rows x 37 columns]

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b626b_row0_col0, #T_b626b_row0_col1, #T_b626b_row0_col2, #T_b626b_row0_col3, #T_b626b_row0_col5, #T_b626b_row0_col6, #T_b626b_row0_col7, #T_b626b_row0_col8, #T_b626b_row0_col30, #T_b626b_row0_col32, #T_b626b_row0_col33, #T_b626b_row0_col34, #T_b626b_row0_col35, #T_b626b_row0_col36, #T_b626b_row1_col0, #T_b626b_row1_col1, #T_b626b_row1_col2, #T_b626b_row1_col3, #T_b626b_row1_col5, #T_b626b_row1_col6, #T_b626b_row1_col7, #T_b626b_row1_col8, #T_b626b_row1_col30, #T_b626b_row1_col32, #T_b626b_row1_col33, #T_b626b_row1_col34, #T_b626b_row1_col35, #T_b626b_row1_col36, #T_b626b_row2_col0, #T_b626b_row2_col1, #T_b626b_row2_col2, #T_b626b_row2_col3, #T_b626b_row2_col5, #T_b626b_row2_col6, #T_b626b_row2_col7, #T_b626b_row2_col8, #T_b626b_row2_col30, #T_b626b_row2_col32, #T_b626b_row2_col33, #T_b626b_row2_col34, #T_b626b_row2_col35, #T_b626b_row2_col36, #T_b626b_row3_col0, #T_b626b_row3_col1, #T_b626b_row3_col2, #T_b626b_row3_col3, #T_b626b_row3_col5, #T_b626b_row3_col6, #T_b626b_row3_col7, #T_b626b_row3_col8, #T_b626b_row3_col30, #T_b626b_row3_col32, #T_b626b_row3_col33, #T_b626b_row3_col34, #T_b626b_row3_col35, #T_b626b_row3_col36, #T_b626b_row4_col4, #T_b626b_row5_col0, #T_b626b_row5_col1, #T_b626b_row5_col2, #T_b626b_row5_col3, #T_b626b_row5_col5, #T_b626b_row5_col6, #T_b626b_row5_col7, #T_b626b_row5_col8, #T_b626b_row5_col30, #T_b626b_row5_col32, #T_b626b_row5_col33, #T_b626b_row5_col34, #T_b626b_row5_col35, #T_b626b_row5_col36, #T_b626b_row6_col0, #T_b626b_row6_col1, #T_b626b_row6_col2, #T_b626b_row6_col3, #T_b626b_row6_col5, #T_b626b_row6_col6, #T_b626b_row6_col7, #T_b626b_row6_col8, #T_b626b_row6_col30, #T_b626b_row6_col32, #T_b626b_row6_col33, #T_b626b_row6_col34, #T_b626b_row6_col35, #T_b626b_row6_col36, #T_b626b_row7_col0, #T_b626b_row7_col1, #T_b626b_row7_col2, #T_b626b_row7_col3, #T_b626b_row7_col5, #T_b626b_row7_col6, #T_b626b_row7_col7, #T_b626b_row7_col8, #T_b626b_row7_col30, #T_b626b_row7_col32, #T_b626b_row7_col33, #T_b626b_row7_col34, #T_b626b_row7_col35, #T_b626b_row7_col36, #T_b626b_row8_col0, #T_b626b_row8_col1, #T_b626b_row8_col2, #T_b626b_row8_col3, #T_b626b_row8_col5, #T_b626b_row8_col6, #T_b626b_row8_col7, #T_b626b_row8_col8, #T_b626b_row8_col30, #T_b626b_row8_col32, #T_b626b_row8_col33, #T_b626b_row8_col34, #T_b626b_row8_col35, #T_b626b_row8_col36, #T_b626b_row9_col9, #T_b626b_row10_col10, #T_b626b_row10_col11, #T_b626b_row10_col12, #T_b626b_row10_col13, #T_b626b_row11_col10, #T_b626b_row11_col11, #T_b626b_row11_col12, #T_b626b_row11_col13, #T_b626b_row12_col10, #T_b626b_row12_col11, #T_b626b_row12_col12, #T_b626b_row12_col13, #T_b626b_row13_col10, #T_b626b_row13_col11, #T_b626b_row13_col12, #T_b626b_row13_col13, #T_b626b_row14_col14, #T_b626b_row15_col15, #T_b626b_row15_col16, #T_b626b_row15_col17, #T_b626b_row15_col18, #T_b626b_row16_col15, #T_b626b_row16_col16, #T_b626b_row16_col17, #T_b626b_row16_col18, #T_b626b_row17_col15, #T_b626b_row17_col16, #T_b626b_row17_col17, #T_b626b_row17_col18, #T_b626b_row18_col15, #T_b626b_row18_col16, #T_b626b_row18_col17, #T_b626b_row18_col18, #T_b626b_row19_col19, #T_b626b_row20_col20, #T_b626b_row20_col21, #T_b626b_row20_col22, #T_b626b_row20_col23, #T_b626b_row21_col20, #T_b626b_row21_col21, #T_b626b_row21_col22, #T_b626b_row21_col23, #T_b626b_row22_col20, #T_b626b_row22_col21, #T_b626b_row22_col22, #T_b626b_row22_col23, #T_b626b_row23_col20, #T_b626b_row23_col21, #T_b626b_row23_col22, #T_b626b_row23_col23, #T_b626b_row24_col24, #T_b626b_row25_col25, #T_b626b_row25_col26, #T_b626b_row25_col27, #T_b626b_row25_col28, #T_b626b_row26_col25, #T_b626b_row26_col26, #T_b626b_row26_col27, #T_b626b_row26_col28, #T_b626b_row27_col25, #T_b626b_row27_col26, #T_b626b_row27_col27, #T_b626b_row27_col28, #T_b626b_row28_col25, #T_b626b_row28_col26, #T_b626b_row28_col27, #T_b626b_row28_col28, #T_b626b_row29_col29, #T_b626b_row30_col0, #T_b626b_row30_col1, #T_b626b_row30_col2, #T_b626b_row30_col3, #T_b626b_row30_col5, #T_b626b_row30_col6, #T_b626b_row30_col7, #T_b626b_row30_col8, #T_b626b ...
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b626b_row0_col4, #T_b626b_row3_col4, #T_b626b_row30_col4 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_b626b_row0_col9, #T_b626b_row0_col14, #T_b626b_row1_col9, #T_b626b_row1_col14, #T_b626b_row1_col19, #T_b626b_row2_col14, #T_b626b_row3_col14, #T_b626b_row6_col29, #T_b626b_row30_col14, #T_b626b_row32_col9, #T_b626b_row32_col14, #T_b626b_row32_col19, #T_b626b_row33_col14, #T_b626b_row33_col19, #T_b626b_row33_col29, #T_b626b_row34_col14, #T_b626b_row34_col19, #T_b626b_row34_col24, #T_b626b_row34_col29, #T_b626b_row35_col14, #T_b626b_row35_col19, #T_b626b_row35_col24, #T_b626b_row36_col14 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_b626b_row0_col10, #T_b626b_row0_col11, #T_b626b_row0_col12, #T_b626b_row0_col13, #T_b626b_row1_col10, #T_b626b_row1_col11, #T_b626b_row1_col12, #T_b626b_row1_col13, #T_b626b_row2_col10, #T_b626b_row2_col11, #T_b626b_row2_col12, #T_b626b_row2_col13, #T_b626b_row3_col10, #T_b626b_row3_col11, #T_b626b_row3_col12, #T_b626b_row3_col13, #T_b626b_row5_col10, #T_b626b_row5_col11, #T_b626b_row5_col12, #T_b626b_row5_col13, #T_b626b_row6_col10, #T_b626b_row6_col11, #T_b626b_row6_col12, #T_b626b_row6_col13, #T_b626b_row7_col10, #T_b626b_row7_col11, #T_b626b_row7_col12, #T_b626b_row7_col13, #T_b626b_row8_col10, #T_b626b_row8_col11, #T_b626b_row8_col12, #T_b626b_row8_col13, #T_b626b_row10_col0, #T_b626b_row10_col1, #T_b626b_row10_col2, #T_b626b_row10_col3, #T_b626b_row10_col5, #T_b626b_row10_col6, #T_b626b_row10_col7, #T_b626b_row10_col8, #T_b626b_row10_col30, #T_b626b_row10_col32, #T_b626b_row10_col33, #T_b626b_row10_col34, #T_b626b_row10_col35, #T_b626b_row10_col36, #T_b626b_row11_col0, #T_b626b_row11_col1, #T_b626b_row11_col2, #T_b626b_row11_col3, #T_b626b_row11_col5, #T_b626b_row11_col6, #T_b626b_row11_col7, #T_b626b_row11_col8, #T_b626b_row11_col25, #T_b626b_row11_col26, #T_b626b_row11_col27, #T_b626b_row11_col28, #T_b626b_row11_col30, #T_b626b_row11_col32, #T_b626b_row11_col33, #T_b626b_row11_col34, #T_b626b_row11_col35, #T_b626b_row11_col36, #T_b626b_row12_col0, #T_b626b_row12_col1, #T_b626b_row12_col2, #T_b626b_row12_col3, #T_b626b_row12_col5, #T_b626b_row12_col6, #T_b626b_row12_col7, #T_b626b_row12_col8, #T_b626b_row12_col30, #T_b626b_row12_col32, #T_b626b_row12_col33, #T_b626b_row12_col34, #T_b626b

# %%
correlation = df.corr()[target]
correlation = correlation[abs(correlation) > 0.9]
correlation = correlation[correlation.index != target]
correlation
# Out:
# Open          0.999581
# High          0.999655
# Low           0.999670
# Close         0.999729
# spy_open      0.998673
# spy_high      0.998650
# spy_low       0.998805
# spy_close     0.998785
# goog_open     0.983920
# goog_high     0.983978
# goog_low      0.984032
# goog_close    0.984065
# aapl_open     0.961495
# aapl_high     0.961423
# aapl_low      0.961755
# aapl_close    0.961624
# amzn_open     0.958319
# amzn_high     0.958432
# amzn_low      0.958469
# amzn_close    0.958536
# msft_open     0.964487
# msft_high     0.964462
# msft_low      0.964595
# msft_close    0.964565
# ema_5         0.999567
# ema_10        0.999301
# ema_20        0.998788
# ema_50        0.997469
# ema_100       0.995433
# Name: Close_lead1, dtype: float64

# %%
# features = correlation.index.tolist()
# features = ['Open','High','Low','Close']
features = ['Close']

features
# Out:
# ['Close']

# %%
class SequenceDataset(Dataset):
    def __init__(self, dataframe, target, features, sequence_length=5):
        self.features = features
        self.target = target
        self.sequence_length = sequence_length
        self.y = torch.tensor(dataframe[self.target].values).float()
        self.X = torch.tensor(dataframe[self.features].values).float()

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, i):
        if i >= self.sequence_length - 1:
            i_start = i - self.sequence_length + 1
            x = self.X[i_start:(i + 1), :]
        else:
            padding = self.X[0].repeat(self.sequence_length - i - 1, 1)
            x = self.X[0:(i + 1), :]
            x = torch.cat((padding, x), 0)

        return x, self.y[i]

# %%
i = 4
sequence_length = 4

train_dataset = SequenceDataset(
    df_train,
    target=target,
    features=features,
    sequence_length=sequence_length
)

X, y = train_dataset[i]
print(X)
# Out:
# tensor([[-1.0142],
#         [-1.0185],
#         [-1.0177],
#         [-1.0036]])

# %%
train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True)
X, y = next(iter(train_loader))
print(X.shape)
print(X)
# Out:
# torch.Size([1, 4, 1])
# tensor([[[1.5696],
#          [1.6070],
#          [1.6442],
#          [1.6831]]])

# %%
torch.manual_seed(101)
np.random.seed(101)
#################################
batch_size = 32
sequence_length = 90
#################################
train_dataset = SequenceDataset(
    df_train,
    target=target,
    features=features,
    sequence_length=sequence_length
)
val_dataset = SequenceDataset(
    df_val,
    target=target,
    features=features,
    sequence_length=sequence_length
)
test_dataset = SequenceDataset(
    df_test,
    target=target,
    features=features,
    sequence_length=sequence_length
)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
class ResBlock(torch.nn.Module):
    def __init__(self, in_channels, out_channels, filter, kernel_size=3, stride=1, padding=1):
        super(ResBlock, self).__init__()
        self.conv1 = torch.nn.Conv1d(in_channels, filter, kernel_size, stride, padding)
        self.conv2 = torch.nn.Conv1d(filter, filter, kernel_size, stride, padding)
        self.linear = torch.nn.Linear(filter, out_channels)
        self.relu = torch.nn.ReLU()
        self.bn1 = torch.nn.BatchNorm1d(filter, eps=1e-5)
        self.bn2 = torch.nn.BatchNorm1d(filter, eps=1e-5)
        self.dropout = nn.Dropout(0.2)
        self.weight = nn.Parameter(torch.zeros(1)).to(device)

    def forward(self, x):
        out = self.conv1(x)
        out = self.relu(out)
        out = self.bn1(out)

        out = self.dropout(out)

        out = self.conv2(out)
        out = self.relu(out)
        out = self.bn2(out)

        out = out.view(out.size(0), -1)
        out = self.linear(out)
        out = self.weight*out
        out += x.view(x.size(0), -1)
        return out

# %%
class ResNLS(torch.nn.Module):
    def __init__(self, in_channels, out_channels, hidden_layer, num_layer, num_feature=4, filter=64, kernel_size=3, dropout=0.2, bidirectional=False):
        super(ResNLS, self).__init__()
        self.resblock = torch.nn.ModuleList([ResBlock(in_channels, in_channels, filter) for i in range(num_feature)])
        self.bidirectional=bidirectional
        self.num_layers = num_layer
        self.hidden_layer = hidden_layer
        self.lstm = torch.nn.LSTM(num_feature, hidden_layer, num_layer, batch_first=True,dropout=dropout,bidirectional=bidirectional)
        self.linear = torch.nn.Linear(hidden_layer, out_channels)


    def forward(self, x):
        batch_size = x.size(0)
        out = torch.split(x, 1, 2)
        out_res = []

        for i in range(len(out)):
            out_res.append(self.resblock[i](out[i]))
        out = torch.stack(out_res, 2)

        h0 = torch.zeros(self.num_layers+self.num_layers*self.bidirectional, batch_size, self.hidden_layer).to(device).requires_grad_()
        c0 = torch.zeros(self.num_layers+self.num_layers*self.bidirectional, batch_size, self.hidden_layer).to(device).requires_grad_()
        _, (hn, _) = self.lstm(out, (h0, c0))
        out = self.linear(hn[-1]).flatten()
        return out

# %%
num_consecutive_days = sequence_length
days_pred = 1
num_lstm_hiddensize = 256
lstm_layers = 1
num_features = len(features)
filters = 64
kernel_size = 3
dropout_lstm = 0.2
bidirectional = False

model = ResNLS(num_consecutive_days,
               days_pred,
               num_lstm_hiddensize,
               lstm_layers,
               num_features,
               filters,
               kernel_size,
               dropout_lstm,
               bidirectional)
model.to(device)

summary(model, input_size=(batch_size, num_consecutive_days, num_features))
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:83: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ResNLS                                   [32]                      --
# ├─ModuleList: 1-1                        --                        --
# │    └─ResBlock: 2-1                     [32, 90]                  --
# │    │    └─Conv1d: 3-1                  [32, 64, 1]               17,344
# │    │    └─ReLU: 3-2                    [32, 64, 1]               --
# │    │    └─BatchNorm1d: 3-3             [32, 64, 1]               128
# │    │    └─Dropout: 3-4                 [32, 64, 1]               --
# │    │    └─Conv1d: 3-5                  [32, 64, 1]               12,352
# │    │    └─ReLU: 3-6                    [32, 64, 1]               --
# │    │    └─BatchNorm1d: 3-7             [32, 64, 1]               128
# │    │    └─Linear: 3-8                  [32, 90]                  5,850
# ├─LSTM: 1-2                              [32, 90, 256]             265,216
# ├─Linear: 1-3                            [32, 1]                   257
# ==========================================================================================
# Total params: 301,275
# Trainable params: 301,275
# Non-trainable params: 0
# Total mult-adds (M): 764.98
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 5.99
# Params size (MB): 1.21
# Estimated Total Size (MB): 7.20
# ==========================================================================================

# %%
parameters_to_decay = []
for name, param in model.named_parameters():
    if 'conv1' in name or 'conv2' in name:
        parameters_to_decay.append(param)

weight_decay = 1e-5
learning_rate = 1e-3
optimizer = torch.optim.Adam([{'params': parameters_to_decay, 'weight_decay': weight_decay},
                              {'params': model.lstm.parameters()},
                              {'params': model.linear.parameters()}],
                             lr=learning_rate)
loss_function = nn.MSELoss()

# %%
param_grid = {
    'dropout_lstm': dropout_lstm,
    'weight_decay': weight_decay,
    'learning_rate': learning_rate,
    'num_lstm_hiddensize': num_lstm_hiddensize,
    'lstm_layers': lstm_layers,
    'filters': filters,
    'kernel_size': kernel_size,
    'bidirectional': bidirectional,
    'num_consecutive_days': num_consecutive_days,
    'days_pred': days_pred,
    'num_features': num_features,
    'batch_size': batch_size
}
for key, value in param_grid.items():
    print(f"{key}: {value}")
# Out:
# dropout_lstm: 0.2
# weight_decay: 1e-05
# learning_rate: 0.001
# num_lstm_hiddensize: 256
# lstm_layers: 1
# filters: 64
# kernel_size: 3
# bidirectional: False
# num_consecutive_days: 90
# days_pred: 1
# num_features: 1
# batch_size: 32

# %%
def train_model(data_loader, model, loss_function, optimizer):
    num_batches = len(data_loader)
    total_loss = 0
    model.train()

    for X, y in data_loader:
        X = X.to(device)
        y = y.to(device)
        output = model(X)
        loss = loss_function(output, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    avg_loss = total_loss / num_batches
    print(f"Train loss: {avg_loss}")
    return avg_loss

def test_model(data_loader, model, loss_function, best_val_loss):

    num_batches = len(data_loader)
    total_loss = 0

    model.eval()
    with torch.no_grad():
        for X, y in data_loader:
            X = X.to(device)
            y = y.to(device)
            output = model(X)
            total_loss += loss_function(output, y).item()

    avg_loss = total_loss / num_batches
    print(f"Test loss: {avg_loss}")
    if avg_loss < best_val_loss:
        best_val_loss = avg_loss
        torch.save(model.state_dict(), 'model.pth')
        print('Save new best model')
    return best_val_loss , avg_loss

# %%
best_val_loss = torch.inf
train_losses = []
val_losses = []
for ix_epoch in tqdm(range(100)):
    print(f"Epoch {ix_epoch}\n---------")
    train_losses.append(train_model(train_loader, model, loss_function, optimizer=optimizer))
    best_val_loss,avg_loss = test_model(val_loader, model, loss_function, best_val_loss)
    val_losses.append(avg_loss)
    print()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0
# ---------
# Train loss: 0.07977073060652812
# Test loss: 0.8038980463752523
# Save new best model
#
# Epoch 1
# ---------
# Train loss: 0.004423391505336058
# Test loss: 0.439679445407819
# Save new best model
#
# Epoch 2
# ---------
# Train loss: 0.003432842003906356
# Test loss: 0.2060600997065194
# Save new best model
#
# Epoch 3
# ---------
# Train loss: 0.0031490696780946885
# Test loss: 0.17242598498705775
# Save new best model
#
# Epoch 4
# ---------
# Train loss: 0.0027532820893083547
# Test loss: 0.20069779315963387
#
# Epoch 5
# ---------
# Train loss: 0.002828249987590337
# Test loss: 0.08026778171188198
# Save new best model
#
# Epoch 6
# ---------
# Train loss: 0.002782199161423881
# Test loss: 0.04843484434240963
# Save new best model
#
# Epoch 7
# ---------
# Train loss: 0.002339225468946801
# Test loss: 0.05415663885651156
#
# Epoch 8
# ---------
# Train loss: 0.002441743962868537
# Test loss: 0.07127978303469718
#
# Epoch 9
# ---------
# Train loss: 0.0022394508583426114
# Test loss: 0.04337480993126519
# Save new best model
#
# Epoch 10
# ---------
# Train loss: 0.002037247667284382
# Test loss: 0.019633367657661438
# Save new best model
#
# Epoch 11
# ---------
# Train loss: 0.00206145818670085
# Test loss: 0.04078714453498833
#
# Epoch 12
# ---------
# Train loss: 0.0018601934477168647
# Test loss: 0.03381122529390268
#
# Epoch 13
# ---------
# Train loss: 0.0019743818770474454
# Test loss: 0.06753338006092235
#
# Epoch 14
# ---------
# Train loss: 0.001825789045523702
# Test loss: 0.03845834970707074
#
# Epoch 15
# ---------
# Train loss: 0.0017430187191724057
# Test loss: 0.037443355831783265
#
# Epoch 16
# ---------
# Train loss: 0.0015566466299201092
# Test loss: 0.007338476920267567
# Save new best model
#
# Epoch 17
# ---------
# Train loss: 0.0016766419327224516
# Test loss: 0.00703409691050183
# Save new best model
#
# Epoch 18
# ---------
# Train loss: 0.0015788740687815834
# Test loss: 0.01259804517030716
#
# Epoch 19
# ---------
# Train loss: 0.0016953707022513563
# Test loss: 0.011490675373352133
#
# Epoch 20
# ---------
# Train loss: 0.0014489281792550409
# Test loss: 0.006734767652233131
# Save new best model
#
# Epoch 21
# ---------
# Train loss: 0.001376483442718088
# Test loss: 0.01282853924203664
#
# Epoch 22
# ---------
# Train loss: 0.0014414688416910658
# Test loss: 0.005778468766948208
# Save new best model
#
# Epoch 23
# ---------
# Train loss: 0.0014669928744795821
# Test loss: 0.010428949492052197
#
# Epoch 24
# ---------
# Train loss: 0.001315697978556742
# Test loss: 0.012462542537832633
#
# Epoch 25
# ---------
# Train loss: 0.0013637871295119816
# Test loss: 0.0074063011998077855
#
# Epoch 26
# ---------
# Train loss: 0.0013245801688284583
# Test loss: 0.011666235892334953
#
# Epoch 27
# ---------
# Train loss: 0.0013052599432769292
# Test loss: 0.018106877629179507
#
# Epoch 28
# ---------
# Train loss: 0.0013082919444235403
# Test loss: 0.007138019660487771
#
# Epoch 29
# ---------
# Train loss: 0.001240069620008956
# Test loss: 0.008784587436821312
#
# Epoch 30
# ---------
# Train loss: 0.0013229474138971718
# Test loss: 0.01679954319843091
#
# Epoch 31
# ---------
# Train loss: 0.0013362554138086947
# Test loss: 0.01444321931921877
#
# Epoch 32
# ---------
# Train loss: 0.001247262584295259
# Test loss: 0.013958758761873469
#
# Epoch 33
# ---------
# Train loss: 0.0012818090213958413
# Test loss: 0.013415345194516703
#
# Epoch 34
# ---------
# Train loss: 0.0013034649583137398
# Test loss: 0.008992731251055375
#
# Epoch 35
# ---------
# Train loss: 0.0013722376031857434
# Test loss: 0.015119369694730267
#
# Epoch 36
# ---------
# Train loss: 0.0012174501077219424
# Test loss: 0.011269220223766752
#
# Epoch 37
# ---------
# Train loss: 0.0013630023149157604
# Test loss: 0.0055890107760205865
# Save new best model
#
# Epoch 38
# ---------
# Train loss: 0.0012069858118681418
# Test loss: 0.016091548241092823
#
# Epoch 39
# ---------
# Train loss: 0.001269664604126686
# Test loss: 0.019811176869552583
#
# Epoch 40
# ---------
# Train loss: 0.0011973983350945937
# Test loss: 0.0102698290720582
#
# Epoch 41
# ---------
# Train loss: 0.0013057622336125332
# Test loss: 0.013388533989200369
#
# Epoch 42
# ---------
# Train loss: 0.0012070512260130095
# Test loss: 0.01184886004193686
#
# Epoch 43
# ---------
# Train loss: 0.0014154617425857954
# Test loss: 0.005577173273195513
# Save new best model
#
# Epoch 44
# ---------
# Train loss: 0.0012664479349510775
# Test loss: 0.011483474794658832
#
# Epoch 45
# ---------
# Train loss: 0.0011909191281677435
# Test loss: 0.013817635757732205
#
# Epoch 46
# ---------
# Train loss: 0.0013491660947986548
# Test loss: 0.016670312325004488
#
# Epoch 47
# ---------
# Train loss: 0.001237769421535514
# Test loss: 0.013156550150597468
#
# Epoch 48
# ---------
# Train loss: 0.001414148827954646
# Test loss: 0.012769745997502469
#
# Epoch 49
# ---------
# Train loss: 0.001237061235447219
# Test loss: 0.018440708168782294
#
# Epoch 50
# ---------
# Train loss: 0.001167095536079761
# Test loss: 0.022161607019370422
#
# Epoch 51
# ---------
# Train loss: 0.0013215680058149906
# Test loss: 0.03270442222128622
#
# Epoch 52
# ---------
# Train loss: 0.001280546005047302
# Test loss: 0.0207396530022379
#
# Epoch 53
# ---------
# Train loss: 0.0012741327624215984
# Test loss: 0.024283455190015957
#
# Epoch 54
# ---------
# Train loss: 0.0012583337013512069
# Test loss: 0.03601310290105175
#
# Epoch 55
# ---------
# Train loss: 0.0013100718541893238
# Test loss: 0.019944898202084005
#
# Epoch 56
# ---------
# Train loss: 0.0013697832255274989
# Test loss: 0.024811748415231705
#
# Epoch 57
# ---------
# Train loss: 0.0012329314626948608
# Test loss: 0.04055195543332957
#
# Epoch 58
# ---------
# Train loss: 0.0013163701213113287
# Test loss: 0.03340282007411588
#
# Epoch 59
# ---------
# Train loss: 0.0012230919502701821
# Test loss: 0.024631036445498466
#
# Epoch 60
# ---------
# Train loss: 0.0012493260529158907
# Test loss: 0.03941473690792918
#
# Epoch 61
# ---------
# Train loss: 0.001240201598838828
# Test loss: 0.025543071853462607
#
# Epoch 62
# ---------
# Train loss: 0.001247247723034478
# Test loss: 0.026176853192737326
#
# Epoch 63
# ---------
# Train loss: 0.0012334600936399862
# Test loss: 0.02752333605894819
#
# Epoch 64
# ---------
# Train loss: 0.001201485232506398
# Test loss: 0.013004240958252922
#
# Epoch 65
# ---------
# Train loss: 0.0012808247120119631
# Test loss: 0.01248501161171589
#
# Epoch 66
# ---------
# Train loss: 0.0013498614761403823
# Test loss: 0.05238676903536543
#
# Epoch 67
# ---------
# Train loss: 0.0012040567345402745
# Test loss: 0.05666024496895261
#
# Epoch 68
# ---------
# Train loss: 0.0012155582775331794
# Test loss: 0.05471630912506953
#
# Epoch 69
# ---------
# Train loss: 0.0013436645206257385
# Test loss: 0.03510999647551216
#
# Epoch 70
# ---------
# Train loss: 0.0012668247675924982
# Test loss: 0.032540483691263944
#
# Epoch 71
# ---------
# Train loss: 0.0012099901254142395
# Test loss: 0.03144299378618598
#
# Epoch 72
# ---------
# Train loss: 0.0014889591820387831
# Test loss: 0.014463252940913662
#
# Epoch 73
# ---------
# Train loss: 0.0012266983169191067
# Test loss: 0.09458664586418308
#
# Epoch 74
# ---------
# Train loss: 0.001302385581619737
# Test loss: 0.030552197495126165
#
# Epoch 75
# ---------
# Train loss: 0.0011542157691080994
# Test loss: 0.026682554802391678
#
# Epoch 76
# ---------
# Train loss: 0.00128764390002846
# Test loss: 0.054050607490353286
#
# Epoch 77
# ---------
# Train loss: 0.0012384326511246694
# Test loss: 0.015241820859955624
#
# Epoch 78
# ---------
# Train loss: 0.0012898293064227478
# Test loss: 0.04286965588107705
#
# Epoch 79
# ---------
# Train loss: 0.0012729324030994076
# Test loss: 0.055209638841915876
#
# Epoch 80
# ---------
# Train loss: 0.0011869556795816958
# Test loss: 0.022916461020940915
#
# Epoch 81
# ---------
# Train loss: 0.0012252932051084035
# Test loss: 0.03106278445920907
#
# Epoch 82
# ---------
# Train loss: 0.001330453529062065
# Test loss: 0.014132070762570947
#
# Epoch 83
# ---------
# Train loss: 0.0012184903635868742
# Test loss: 0.021789474471006542
#
# Epoch 84
# ---------
# Train loss: 0.0012395984712413573
# Test loss: 0.029625424853293225
#
# Epoch 85
# ---------
# Train loss: 0.0013372785033425316
# Test loss: 0.024292675079777837
#
# Epoch 86
# ---------
# Train loss: 0.001180706171350809
# Test loss: 0.01838591176783666
#
# Epoch 87
# ---------
# Train loss: 0.0012198969116950812
# Test loss: 0.016729716036934406
#
# Epoch 88
# ---------
# Train loss: 0.0011596833958925168
# Test loss: 0.015289974995539524
#
# Epoch 89
# ---------
# Train loss: 0.0012654152477250223
# Test loss: 0.026641621603630483
#
# Epoch 90
# ---------
# Train loss: 0.0012618182276304241
# Test loss: 0.03390702202159446
#
# Epoch 91
# ---------
# Train loss: 0.0012091588325875496
# Test loss: 0.03072324747336097
#
# Epoch 92
# ---------
# Train loss: 0.0011534490762231495
# Test loss: 0.014872420608298853
#
# Epoch 93
# ---------
# Train loss: 0.0011761601358997605
# Test loss: 0.016733454685891047
#
# Epoch 94
# ---------
# Train loss: 0.0012765538815602345
# Test loss: 0.012164566607680172
#
# Epoch 95
# ---------
# Train loss: 0.0012100707472493541
# Test loss: 0.008864349496434443
#
# Epoch 96
# ---------
# Train loss: 0.0012131004313555276
# Test loss: 0.028736962733091787
#
# Epoch 97
# ---------
# Train loss: 0.0011680280018012009
# Test loss: 0.007863680351874791
#
# Epoch 98
# ---------
# Train loss: 0.0011969485522938831
# Test loss: 0.011096203787019476
#
# Epoch 99
# ---------
# Train loss: 0.0012284637341508642
# Test loss: 0.0052103795314906165
# Save new best model

# %%
def plot_losses(train_loss,val_loss):
  plt.figure(figsize=(30, 10))
  plt.plot(train_loss,color="blue",label="train loss")
  plt.plot(val_loss,color="red",label="val loss")
  plt.xlabel('epoch')
  plt.ylabel('loss')
  plt.legend()
  plt.show()

plot_losses(train_losses,val_losses)

# %%
def predict(data_loader, model):
    output = torch.tensor([])
    model.eval()
    with torch.no_grad():
        for X, _ in data_loader:
            X = X.to(device)
            y_star = model(X)
            output = torch.cat((output, y_star.detach().cpu()), 0)
    return output

# %%
train_eval_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)

ystar_col = "Model forecast"

df_train[ystar_col] = predict(train_eval_loader, model).numpy()
df_val[ystar_col] = predict(val_loader, model).numpy()
df_test[ystar_col] = predict(test_loader, model).numpy()

df_out = None
df_test_out = pd.DataFrame()
df_test_out[target] = df_test[target]
df_test_out[ystar_col] = df_test[ystar_col]

df_out = pd.concat((df_train, df_val, df_test))[[target, ystar_col]]

for c in df_out.columns:
    df_out[c] = df_out[c] * target_stdev + target_mean

for c in df_test_out.columns:
    df_test_out[c] = df_test_out[c] * target_stdev + target_mean

print(df_test_out[[target, ystar_col]])
# Out:
#                            Close_lead1  Model forecast
# Date
# 2022-05-02 00:00:00-04:00  4175.479980     4165.011719
# 2022-05-03 00:00:00-04:00  4300.169922     4180.887695
# 2022-05-04 00:00:00-04:00  4146.870117     4285.627930
# 2022-05-05 00:00:00-04:00  4123.339844     4205.862305
# 2022-05-06 00:00:00-04:00  3991.239990     4141.512695
# ...                                ...             ...
# 2024-05-03 00:00:00-04:00  5180.740234     5097.610352
# 2024-05-06 00:00:00-04:00  5187.700195     5157.443848
# 2024-05-07 00:00:00-04:00  5187.669922     5174.194824
# 2024-05-08 00:00:00-04:00  5214.080078     5172.444336
# 2024-05-09 00:00:00-04:00  5222.680176     5190.307129
#
# [509 rows x 2 columns]

# %%
import numpy as np
import math
from sklearn.metrics import mean_squared_error
def MASE(pred, y):
    pred = torch.tensor(pred)
    y = torch.tensor(y)
    return float(torch.mean(torch.abs(pred - y) / torch.mean(torch.abs(y[1:] - y[:-1]))))

def SMAPE(pred, y):
    pred = torch.tensor(pred)
    y = torch.tensor(y)
    return float(200 * torch.mean(torch.abs(pred - y) / (torch.abs(y) + torch.abs(pred))))

def MAE(pred, y):
    pred = torch.tensor(pred)
    y = torch.tensor(y)
    return float(torch.mean(torch.abs(pred - y)))

def sharp_ratio(pred, y):
    pred = torch.tensor(pred)
    y = torch.tensor(y)
    return float(torch.mean((pred - y) / torch.std(y)))


print( 'best_val_loss =', best_val_loss )
print( 'MSE =', mean_squared_error(df_test_out[target], df_test_out['Model forecast']))
print( 'MASE =', MASE(df_test_out[target], df_test_out['Model forecast']))
print( 'RMSE =', math.sqrt(mean_squared_error(df_test_out[target], df_test_out['Model forecast'])) )
print( 'SMAPE =', SMAPE(df_test_out[target], df_test_out['Model forecast']))
print( 'MAE =', MAE(df_test_out[target], df_test_out['Model forecast']))
print( 'sharp_ratio =', sharp_ratio(df_test_out[target], df_test_out['Model forecast']))
# Out:
# best_val_loss = 0.0052103795314906165
# MSE = 2544.323808046596
# MASE = 1.2441962379732188
# RMSE = 50.44129070559749
# SMAPE = 0.934937850053092
# MAE = 39.11530440354863
# sharp_ratio = -0.006412510080960621

# %%
fig = px.line(df_out, labels={'value': target, 'created_at': 'Date'})
fig.add_vline(x=val_start, line_width=4, line_dash="dash")
fig.add_vline(x=test_start, line_width=4, line_dash="dash")

pio.templates.default = "plotly_white"

plot_template = dict(
    layout=go.Layout({
        "font_size": 18,
        "xaxis_title_font_size": 24,
        "yaxis_title_font_size": 24})
)

fig.update_layout(
  template=plot_template, legend=dict(orientation='h', y=1.02, title_text="")
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d4fe7c3f-ea8b-45b6-a903-dbf1f1844767" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d4fe7c3f-ea8b-45b6-a903-dbf1f1844767")) {                    Plotly.newPlot(                        "d4fe7c3f-ea8b-45b6-a903-dbf1f1844767",                        [{"hovertemplate":"variable=Close_lead1\u003cbr\u003eDate=%{x}\u003cbr\u003eClose_lead1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Close_lead1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Close_lead1","showlegend":true,"x":["2004-08-19T00:00:00-04:00","2004-08-20T00:00:00-04:00","2004-08-23T00:00:00-04:00","2004-08-24T00:00:00-04:00","2004-08-25T00:00:00-04:00","2004-08-26T00:00:00-04:00","2004-08-27T00:00:00-04:00","2004-08-30T00:00:00-04:00","2004-08-31T00:00:00-04:00","2004-09-01T00:00:00-04:00","2004-09-02T00:00:00-04:00","2004-09-03T00:00:00-04:00","2004-09-07T00:00:00-04:00","2004-09-08T00:00:00-04:00","2004-09-09T00:00:00-04:00","2004-09-10T00:00:00-04:00","2004-09-13T00:00:00-04:00","2004-09-14T00:00:00-04:00","2004-09-15T00:00:00-04:00","2004-09-16T00:00:00-04:00","2004-09-17T00:00:00-04:00","2004-09-20T00:00:00-04:00","2004-09-21T00:00:00-04:00","2004-09-22T00:00:00-04:00","2004-09-23T00:00:00-04:00","2004-09-24T00:00:00-04:00","2004-09-27T00:00:00-04:00","2004-09-28T00:00:00-04:00","2004-09-29T00:00:00-04:00","2004-09-30T00:00:00-04:00","2004-10-01T00:00:00-04:00","2004-10-04T00:00:00-04:00","2004-10-05T00:00:00-04:00","2004-10-06T00:00:00-04:00","2004-10-07T00:00:00-04:00","2004-10-08T00:00:00-04:00","2004-10-11T00:00:00-04:00","2004-10-12T00:00:00-04:00","2004-10-13T00:00:00-04:00","2004-10-14T00:00:00-04:00","2004-10-15T00:00:00-04:00","2004-10-18T00:00:00-04:00","2004-10-19T00:00:00-04:00","2004-10-20T00:00:00-04:00","2004-10-21T00:00:00-04:00","2004-10-22T00:00:00-04:00","2004-10-25T00:00:00-04:00","2004-10-26T00:00:00-04:00","2004-10-27T00:00:00-04:00","2004-10-28T00:00:00-04:00","2004-10-29T00:00:00-04:00","2004-11-01T00:00:00-05:00","2004-11-02T00:00:00-05:00","2004-11-03T00:00:00-05:00","2004-11-04T00:00:00-05:00","2004-11-05T00:00:00-05:00","2004-11-08T00:00:00-05:00","2004-11-09T00:00:00-05:00","2004-11-10T00:00:00-05:00","2004-11-11T00:00:00-05:00","2004-11-12T00:00:00-05:00","2004-11-15T00:00:00-05:00","2004-11-16T00:00:00-05:00","2004-11-17T00:00:00-05:00","2004-11-18T00:00:00-05:00","2004-11-19T00:00:00-05:00","2004-11-22T00:00:00-05:00","2004-11-23T00:00:00-05:00","2004-11-24T00:00:00-05:00","2004-11-26T00:00:00-05:00","2004-11-29T00:00:00-05:00","2004-11-30T00:00:00-05:00","2004-12-01T00:00:00-05:00","2004-12-02T00:00:00-05:00","2004-12-03T00:00:00-05:00","2004-12-06T00:00:00-05:00","2004-12-07T00:00:00-05:00","2004-12-08T00:00:00-05:00","2004-12-09T00:00:00-05:00","2004-12-10T00:00:00-05:00","2004-12-13T00:00:00-05:00","2004-12-14T00:00:00-05:00","2004-12-15T00:00:00-05:00","2004-12-16T00:00:00-05:00","2004-12-17T00:00:00-05:00","2004-12-20T00:00:00-05:00","2004-12-21T00:00:00-05:00","2004-12-22T00:00:00-05:00","2004-12-23T00:00:00-05:00","2004-12-27T00:00:00-05:00","2004-12-28T00:00:00-05:00","2004-12-29T00:00:00-05:00","2004-12-30T00:00:00-05:00","2004-12-31T00:00:00-05:00","2005-01-03T00:00:00-05:00","2005-01-04T00:00:00-05:00","2005-01-05T00:00:00-05:00","2005-01-06T00:00:00-05:00","2005-01-07T00:00:00-05:00","2005-01-10T00:00:00-05:00","2005-01-11T00:00:00-05:00","2005-01-12T00:00:00-05:00","2005-01-13T00:00:00-05:00","2005-01-14T00:00:00-05:00","2005-01-18T00:00:00-05:00","2005-01-19T00:00:00-05:00","2005-01-20T00:00:00-05:00","2005-01-21T00:00:00-05:00","2005-01-24T00:00:00-05:00","2005-01-25T00:00:00-05:00","2005-01-26T00:00:00-05:00","2005-01-27T00:00:00-05:00","2005-01- ...

# %%
fig = px.line(df_test_out[[target, ystar_col]], labels={'value': target, 'created_at': 'Date'})

pio.templates.default = "plotly_white"

plot_template = dict(
    layout=go.Layout({
        "font_size": 18,
        "xaxis_title_font_size": 24,
        "yaxis_title_font_size": 24})
)

fig.update_layout(
  template=plot_template, legend=dict(orientation='h', y=1.02, title_text="")
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="12352262-3f97-454d-87e7-3900d69f3990" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12352262-3f97-454d-87e7-3900d69f3990")) {                    Plotly.newPlot(                        "12352262-3f97-454d-87e7-3900d69f3990",                        [{"hovertemplate":"variable=Close_lead1\u003cbr\u003eDate=%{x}\u003cbr\u003eClose_lead1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Close_lead1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Close_lead1","showlegend":true,"x":["2022-05-02T00:00:00-04:00","2022-05-03T00:00:00-04:00","2022-05-04T00:00:00-04:00","2022-05-05T00:00:00-04:00","2022-05-06T00:00:00-04:00","2022-05-09T00:00:00-04:00","2022-05-10T00:00:00-04:00","2022-05-11T00:00:00-04:00","2022-05-12T00:00:00-04:00","2022-05-13T00:00:00-04:00","2022-05-16T00:00:00-04:00","2022-05-17T00:00:00-04:00","2022-05-18T00:00:00-04:00","2022-05-19T00:00:00-04:00","2022-05-20T00:00:00-04:00","2022-05-23T00:00:00-04:00","2022-05-24T00:00:00-04:00","2022-05-25T00:00:00-04:00","2022-05-26T00:00:00-04:00","2022-05-27T00:00:00-04:00","2022-05-31T00:00:00-04:00","2022-06-01T00:00:00-04:00","2022-06-02T00:00:00-04:00","2022-06-03T00:00:00-04:00","2022-06-06T00:00:00-04:00","2022-06-07T00:00:00-04:00","2022-06-08T00:00:00-04:00","2022-06-09T00:00:00-04:00","2022-06-10T00:00:00-04:00","2022-06-13T00:00:00-04:00","2022-06-14T00:00:00-04:00","2022-06-15T00:00:00-04:00","2022-06-16T00:00:00-04:00","2022-06-17T00:00:00-04:00","2022-06-21T00:00:00-04:00","2022-06-22T00:00:00-04:00","2022-06-23T00:00:00-04:00","2022-06-24T00:00:00-04:00","2022-06-27T00:00:00-04:00","2022-06-28T00:00:00-04:00","2022-06-29T00:00:00-04:00","2022-06-30T00:00:00-04:00","2022-07-01T00:00:00-04:00","2022-07-05T00:00:00-04:00","2022-07-06T00:00:00-04:00","2022-07-07T00:00:00-04:00","2022-07-08T00:00:00-04:00","2022-07-11T00:00:00-04:00","2022-07-12T00:00:00-04:00","2022-07-13T00:00:00-04:00","2022-07-14T00:00:00-04:00","2022-07-15T00:00:00-04:00","2022-07-18T00:00:00-04:00","2022-07-19T00:00:00-04:00","2022-07-20T00:00:00-04:00","2022-07-21T00:00:00-04:00","2022-07-22T00:00:00-04:00","2022-07-25T00:00:00-04:00","2022-07-26T00:00:00-04:00","2022-07-27T00:00:00-04:00","2022-07-28T00:00:00-04:00","2022-07-29T00:00:00-04:00","2022-08-01T00:00:00-04:00","2022-08-02T00:00:00-04:00","2022-08-03T00:00:00-04:00","2022-08-04T00:00:00-04:00","2022-08-05T00:00:00-04:00","2022-08-08T00:00:00-04:00","2022-08-09T00:00:00-04:00","2022-08-10T00:00:00-04:00","2022-08-11T00:00:00-04:00","2022-08-12T00:00:00-04:00","2022-08-15T00:00:00-04:00","2022-08-16T00:00:00-04:00","2022-08-17T00:00:00-04:00","2022-08-18T00:00:00-04:00","2022-08-19T00:00:00-04:00","2022-08-22T00:00:00-04:00","2022-08-23T00:00:00-04:00","2022-08-24T00:00:00-04:00","2022-08-25T00:00:00-04:00","2022-08-26T00:00:00-04:00","2022-08-29T00:00:00-04:00","2022-08-30T00:00:00-04:00","2022-08-31T00:00:00-04:00","2022-09-01T00:00:00-04:00","2022-09-02T00:00:00-04:00","2022-09-06T00:00:00-04:00","2022-09-07T00:00:00-04:00","2022-09-08T00:00:00-04:00","2022-09-09T00:00:00-04:00","2022-09-12T00:00:00-04:00","2022-09-13T00:00:00-04:00","2022-09-14T00:00:00-04:00","2022-09-15T00:00:00-04:00","2022-09-16T00:00:00-04:00","2022-09-19T00:00:00-04:00","2022-09-20T00:00:00-04:00","2022-09-21T00:00:00-04:00","2022-09-22T00:00:00-04:00","2022-09-23T00:00:00-04:00","2022-09-26T00:00:00-04:00","2022-09-27T00:00:00-04:00","2022-09-28T00:00:00-04:00","2022-09-29T00:00:00-04:00","2022-09-30T00:00:00-04:00","2022-10-03T00:00:00-04:00","2022-10-04T00:00:00-04:00","2022-10-05T00:00:00-04:00","2022-10-06T00:00:00-04:00","2022-10-07T00:00:00-04:00","2022-10-10T00:00:00-04:00","2022-10- ...

# %% [markdown]
# # **Simple Trading algorithm**
# > This algorithm simulates a simple trading strategy based on day-to-day price movements and compares the returns with given real values. It tracks buying and selling days, calculates individual and total returns, and provides both expected and real return metrics for evaluation.
#
# - **Buying Condition** : If a stock is not currently held and the real value of the current day is less than the price of the next day, a stock is bought.
#
# - **Selling Condition** : If a stock is currently held and the real value of the current day is greater than the price of the next day, the stock is sold.
#
# - **expected_return** : The total expected return from the trading strategy, expressed as a percentage.
#
# - **real_return** : The total real return from the trading strategy, expressed as a percentage.
#
# - **max_expected_return** : The maximum expected return from a single trade, expressed as a percentage.
#
# - **max_real_return** : The maximum real return from a single trade, expressed as a percentage.

# %%
def buy_sell_stock_v2(prices,real):
    buy_days = []
    sell_days = []
    current_bought= None
    returns = []
    real_current_bought= None
    real_returns = []
    holding = False  # Flag to indicate if we're holding a stock

    for i in range(len(prices)-1):
        if  holding and real[i] > prices[i + 1] :
            holding = False
            sell_days.append(prices.index[i])
            # Calculating rate of return
            returns.append(((prices[i] - current_bought) / current_bought)+1)
            real_returns.append(((real[i] - real_current_bought) / real_current_bought)+1)

        elif not holding and real[i] < prices[i + 1]:
            buy_days.append(prices.index[i])
            holding = True
            current_bought = prices[i]
            real_current_bought = real[i]

    returns = np.array(returns)
    expected_return = (np.prod(returns)-1)*100
    max_expected_return = (returns.max()-1)*100

    real_returns = np.array(real_returns)
    real_return = (np.prod(real_returns)-1)*100
    max_real_return =(real_returns.max()-1)*100
    return buy_days, sell_days, expected_return,real_return,max_expected_return,max_real_return,returns,real_returns

    # explain this algorithm


def plot_stock_prices(prices,real, buy_days, sell_days):
    plt.figure(figsize=(30, 10))
    plt.plot(prices.index, prices.values, label='Pred Stock Prices')
    plt.plot(real.index, real.values, label='Real Stock Prices')
    plt.scatter(buy_days, prices.loc[buy_days], color='green', marker='^', label='Buy')
    plt.scatter(sell_days, prices.loc[sell_days], color='red', marker='v', label='Sell')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.title('Stock Prices with Buy/Sell Signals')
    plt.legend()
    plt.xticks(rotation=45)
    plt.show()

# %%
buy_days, sell_days, expected_return, real_return,max_expected_return,max_real_return,returns,real_returns =  buy_sell_stock_v2( df_test_out['Model forecast'],df_test_out[target] )
print("expected_return =",expected_return,"%")
print("real_return =",real_return,"%")
print("max_expected_return =",max_expected_return,"%")
print("max_real_return =",max_real_return,"%")
# Out:
# expected_return = -37.91815115018385 %
# real_return = 7.671415940569837 %
# max_expected_return = 3.512844815850258 %
# max_real_return = 5.0389037363598455 %

# %%
plot_stock_prices( df_test_out['Model forecast'], df_test_out[target], buy_days, sell_days)

# %% [markdown]
# # **Local minima & maxima Trading algorithm**
# >This algorithm simulates a simple trading strategy based on identifying local minima and maxima in the price data. It tracks buying and selling days, calculates individual and total returns, and provides both expected and real return metrics for evaluation. The strategy buys at local minima and sells at local maxima, aiming to maximize returns by exploiting short-term price movements.
#
# - **Buying Condition** : If a stock is not currently held and the current price is lower than both the previous day and the next day, a stock is bought.
#
# - **Selling Condition** : If a stock is currently held and the current price is higher than both the previous day and the next day, the stock is sold

# %%
def buy_sell_stock(prices,real):
    buy_days = []
    sell_days = []
    current_bought= None
    returns = []
    real_current_bought= None
    real_returns = []
    holding = False  # Flag to indicate if we're holding a stock

    for i in range(1, len(prices)-1):
        if  holding and prices[i] > prices[i - 1] and prices[i] > prices[i + 1]:
            holding = False
            sell_days.append(prices.index[i])
            # Calculating rate of return
            returns.append(((prices[i] - current_bought) / current_bought)+1)
            real_returns.append(((real[i] - real_current_bought) / real_current_bought)+1)

        elif not holding and prices[i] < prices[i - 1] and prices[i] < prices[i + 1]:
            buy_days.append(prices.index[i])
            holding = True
            current_bought = prices[i]
            real_current_bought = real[i]

    returns = np.array(returns)
    expected_return = (np.prod(returns)-1)*100
    max_expected_return = (returns.max()-1)*100

    real_returns = np.array(real_returns)
    real_return = (np.prod(real_returns)-1)*100
    max_real_return =(real_returns.max()-1)*100
    return buy_days, sell_days, expected_return,real_return,max_expected_return,max_real_return,returns,real_returns

# %%
buy_days, sell_days, expected_return, real_return,max_expected_return,max_real_return,returns,real_returns =  buy_sell_stock( df_test_out['Model forecast'],df_test_out[target]  )
print("expected_return =",expected_return,"%")
print("real_return =",real_return,"%")
print("max_expected_return =",max_expected_return,"%")
print("max_real_return =",max_real_return,"%")
# Out:
# expected_return = 630.8362617894743 %
# real_return = 5.831650211576722 %
# max_expected_return = 7.7541783452034 %
# max_real_return = 4.332567306803292 %

# %%
plot_stock_prices(df_test_out['Model forecast'],df_test_out[target] , buy_days, sell_days)

# %% [markdown]
# # Grid search for Optimize parameter

# %%
def grid_search(param_combinations):
    best_val_loss_sin = torch.inf
    best_val_loss_list = []
    best_train_loss_list = []
    best_params = None
    best_val_loss = torch.inf
    best_model = None
    best_train_dataloader = None
    best_val_dataloader = None
    best_test_dataloader = None

    for params in tqdm(param_combinations):
        print(params)
        dropout_lstm, weight_decay, learning_rate, num_lstm_hiddensize, lstm_layers, filters, kernel_size, bidirectional, num_consecutive_days, days_pred, num_features, batch_size = params
        model = ResNLS(num_consecutive_days,
                       days_pred,
                       num_lstm_hiddensize,
                       lstm_layers,
                       num_features,
                       filters,
                       kernel_size,
                       dropout_lstm,
                       bidirectional)
        model.to(device)

        train_dataset = SequenceDataset(
            df_train,
            target=target,
            features=features,
            sequence_length=num_consecutive_days
        )
        val_dataset = SequenceDataset(
            df_val,
            target=target,
            features=features,
            sequence_length=num_consecutive_days
        )
        test_dataset = SequenceDataset(
            df_test,
            target=target,
            features=features,
            sequence_length=num_consecutive_days
        )
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

        parameters_to_decay = []
        for name, param in model.named_parameters():
            if 'conv1' in name or 'conv2' in name:
                parameters_to_decay.append(param)

        optimizer = torch.optim.Adam([
            {'params': parameters_to_decay, 'weight_decay': weight_decay},
            {'params': model.lstm.parameters()},
            {'params': model.linear.parameters()}
        ], lr=learning_rate)

        loss_function = nn.MSELoss()

        train_losses = []
        val_losses = []
        for ix_epoch in range(150):
            print(f"Epoch {ix_epoch}\n---------")
            train_losses.append(train_model(train_loader, model, loss_function, optimizer=optimizer))
            best_val_loss, avg_loss = test_model(val_loader, model, loss_function, best_val_loss)
            val_losses.append(avg_loss)
            print()

        if best_val_loss < best_val_loss_sin:
            best_params = params
            best_val_loss_list = val_losses
            best_train_loss_list = train_losses
            best_val_loss_sin = best_val_loss
            best_train_dataloader = train_loader
            best_val_dataloader = val_loader
            best_test_dataloader = test_loader
            best_model = model

    print(f"Best params: {best_params}")
    print(f"Best val loss: {best_val_loss_sin}")
    plot_losses(best_train_loss_list, best_val_loss_list)

    ystar_col = "Model forecast"

    df_train[ystar_col] = predict(best_train_dataloader, best_model).numpy()
    df_val[ystar_col] = predict(best_val_dataloader, best_model).numpy()
    df_test[ystar_col] = predict(best_test_dataloader, best_model).numpy()

    df_out = None
    df_test_out = pd.DataFrame()
    df_test_out[target] = df_test[target]
    df_test_out[ystar_col] = df_test[ystar_col]

    df_out = pd.concat((df_train, df_val, df_test))[[target, ystar_col]]

    for c in df_out.columns:
        df_out[c] = df_out[c] * target_stdev + target_mean

    for c in df_test_out.columns:
        df_test_out[c] = df_test_out[c] * target_stdev + target_mean

    print(df_test_out[[target, ystar_col]])

    print( 'best_val_loss =', best_val_loss )
    print( 'MSE =', mean_squared_error(df_test[target], df_test['Model forecast']))
    print( 'MASE =', MASE(df_test_out[target], df_test_out['Model forecast']))
    print( 'RMSE =', math.sqrt(mean_squared_error(df_test_out[target], df_test_out['Model forecast'])) )
    print( 'SMAPE =', SMAPE(df_test_out[target], df_test_out['Model forecast']))
    print( 'MAE =', MAE(df_test_out[target], df_test_out['Model forecast']))
    print( 'sharp_ratio =', sharp_ratio(df_test_out[target], df_test_out['Model forecast']))

    plt.figure(figsize=(20, 7))
    plt.plot(df_test_out[target], label='True')
    plt.plot(df_test_out[ystar_col], label='Forecast')
    plt.legend()

    return best_params

def copy_from_best(best_params):
    dropout_lstm, weight_decay, learning_rate, num_lstm_hiddensize, lstm_layers, filters, kernel_size, bidirectional, num_consecutive_days, days_pred, num_features, batch_size = best_params
    param_grid = {
      'dropout_lstm': [dropout_lstm],
      'weight_decay': [weight_decay],
      'learning_rate': [learning_rate],
      'num_lstm_hiddensize': [num_lstm_hiddensize],
      'lstm_layers': [lstm_layers],
      'filters': [filters],
      'kernel_size': [kernel_size],
      'bidirectional': [bidirectional],
      'num_consecutive_days': [num_consecutive_days],
      'days_pred': [days_pred],
      'num_features': [num_features],
      'batch_size': [batch_size]
    }
    return param_grid

# %%
param_grid = {
    'dropout_lstm': [dropout_lstm],
    'weight_decay': [weight_decay],
    'learning_rate': [learning_rate],
    'num_lstm_hiddensize': [num_lstm_hiddensize],
    'lstm_layers': [lstm_layers],
    'filters': [filters],
    'kernel_size': [kernel_size],
    'bidirectional': [bidirectional],
    'num_consecutive_days': [num_consecutive_days],
    'days_pred': [days_pred],
    'num_features': [num_features],
    'batch_size': [batch_size]
}

# %%
param_grid = copy_from_best(list(product(*param_grid.values()))[0])
param_grid['weight_decay'] = [1e-4, 1e-5]
param_grid['learning_rate'] = [1e-3,5e-4]
param_combinations = list(product(*param_grid.values()))
best_params = grid_search(param_combinations)
param_grid = copy_from_best(best_params)
for key, value in param_grid.items():
    print(f"{key}: {value}")
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# (0.2, 0.0001, 0.001, 64, 1, 64, 3, False, 60, 1, 1, 32)
# Epoch 0
# ---------
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:83: UserWarning:
#
# dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
# Train loss: 0.1731083038302454
# Test loss: 1.6247229111613706
# Save new best model
#
# Epoch 1
# ---------
# Train loss: 0.004298256573102046
# Test loss: 1.0601578960195184
# Save new best model
#
# Epoch 2
# ---------
# Train loss: 0.0034975688406942234
# Test loss: 0.6334810825646855
# Save new best model
#
# Epoch 3
# ---------
# Train loss: 0.0029833240940558515
# Test loss: 0.4096843290608376
# Save new best model
#
# Epoch 4
# ---------
# Train loss: 0.002635518108182887
# Test loss: 0.26077657217683736
# Save new best model
#
# Epoch 5
# ---------
# Train loss: 0.002632296764791282
# Test loss: 0.23022538790246472
# Save new best model
#
# Epoch 6
# ---------
# Train loss: 0.002825265339080004
# Test loss: 0.2222159070079215
# Save new best model
#
# Epoch 7
# ---------
# Train loss: 0.002599238257032759
# Test loss: 0.20715706516057253
# Save new best model
#
# Epoch 8
# ---------
# Train loss: 0.0022376733099771363
# Test loss: 0.15812012366950512
# Save new best model
#
# Epoch 9
# ---------
# Train loss: 0.0022343565698622935
# Test loss: 0.15309745556442067
# Save new best model
#
# Epoch 10
# ---------
# Train loss: 0.0021920244710805317
# Test loss: 0.14545418578200042
# Save new best model
#
# Epoch 11
# ---------
# Train loss: 0.0020537171686526327
# Test loss: 0.1240978161804378
# Save new best model
#
# Epoch 12
# ---------
# Train loss: 0.0021368324739723314
# Test loss: 0.10504221019800752
# Save new best model
#
# Epoch 13
# ---------
# Train loss: 0.001958322263230765
# Test loss: 0.07898866958566941
# Save new best model
#
# Epoch 14
# ---------
# Train loss: 0.0018483883379245057
# Test loss: 0.09647757245693356
#
# Epoch 15
# ---------
# Train loss: 0.001796208539857499
# Test loss: 0.09395663946634158
#
# Epoch 16
# ---------
# Train loss: 0.0018272434991236115
# Test loss: 0.09403123773518018
#
# Epoch 17
# ---------
# Train loss: 0.0017571688743285654
# Test loss: 0.08617150411009789
#
# Epoch 18
# ---------
# Train loss: 0.0017862514829293133
# Test loss: 0.11297673103399575
#
# Epoch 19
# ---------
# Train loss: 0.0017577357439515781
# Test loss: 0.060725918170646764
# Save new best model
#
# Epoch 20
# ---------
# Train loss: 0.0015974502727453177
# Test loss: 0.08291476563317701
#
# Epoch 21
# ---------
# Train loss: 0.0017118899674143553
# Test loss: 0.05095936395809986
# Save new best model
#
# Epoch 22
# ---------
# Train loss: 0.0015516376741053987
# Test loss: 0.0666911241132766
#
# Epoch 23
# ---------
# Train loss: 0.0015615092974434037
# Test loss: 0.08470149809727445
#
# Epoch 24
# ---------
# Train loss: 0.0014667516584121322
# Test loss: 0.07845395477488637
#
# Epoch 25
# ---------
# Train loss: 0.0015484415038841807
# Test loss: 0.06603653845377266
#
# Epoch 26
# ---------
# Train loss: 0.0015070675656334647
# Test loss: 0.04186135236523114
# Save new best model
#
# Epoch 27
# ---------
# Train loss: 0.0013588672635735074
# Test loss: 0.04112948391411919
# Save new best model
#
# Epoch 28
# ---------
# Train loss: 0.0013733262425258516
# Test loss: 0.03343695367220789
# Save new best model
#
# Epoch 29
# ---------
# Train loss: 0.001424271368793392
# Test loss: 0.04163891986536328
#
# Epoch 30
# ---------
# Train loss: 0.0015434021113305202
# Test loss: 0.03308633058622945
# Save new best model
#
# Epoch 31
# ---------
# Train loss: 0.0013107920261268924
# Test loss: 0.03481605296838097
#
# Epoch 32
# ---------
# Train loss: 0.0012737616414069048
# Test loss: 0.013328259534318931
# Save new best model
#
# Epoch 33
# ---------
# Train loss: 0.0013442284872590175
# Test loss: 0.043168386415345594
#
# Epoch 34
# ---------
# Train loss: 0.0012584852823150164
# Test loss: 0.027967280620941892
#
# Epoch 35
# ---------
# Train loss: 0.0012575847964223113
# Test loss: 0.025174455498927273
#
# Epoch 36
# ---------
# Train loss: 0.001261111428081471
# Test loss: 0.013335606810869649
#
# Epoch 37
# ---------
# Train loss: 0.001434191149113054
# Test loss: 0.03695077740121633
#
# Epoch 38
# ---------
# Train loss: 0.001300160870971834
# Test loss: 0.006982495979173109
# Save new best model
#
# Epoch 39
# ---------
# Train loss: 0.0012501842530553168
# Test loss: 0.016659685425111093
#
# Epoch 40
# ---------
# Train loss: 0.0013323127258768035
# Test loss: 0.01848420040914789
#
# Epoch 41
# ---------
# Train loss: 0.0012688087081187405
# Test loss: 0.014420054445508868
#
# Epoch 42
# ---------
# Train loss: 0.001283596485483295
# Test loss: 0.0237634910736233
#
# Epoch 43
# ---------
# Train loss: 0.0012571910281680644
# Test loss: 0.020851032517384738
#
# Epoch 44
# ---------
# Train loss: 0.001265747070588517
# Test loss: 0.009914791517076083
#
# Epoch 45
# ---------
# Train loss: 0.0011949597249059157
# Test loss: 0.019366392356459983
#
# Epoch 46
# ---------
# Train loss: 0.0012011068801286691
# Test loss: 0.013835070538334548
#
# Epoch 47
# ---------
# Train loss: 0.001175572700430489
# Test loss: 0.011975110552157275
#
# Epoch 48
# ---------
# Train loss: 0.001237240271885023
# Test loss: 0.013769624871201813
#
# Epoch 49
# ---------
# Train loss: 0.001196989720835606
# Test loss: 0.03481549190473743
#
# Epoch 50
# ---------
# Train loss: 0.001262323580674767
# Test loss: 0.015981772274244577
#
# Epoch 51
# ---------
# Train loss: 0.001216986126711427
# Test loss: 0.02068193696322851
#
# Epoch 52
# ---------
# Train loss: 0.0012644518933337813
# Test loss: 0.008739938653889112
#
# Epoch 53
# ---------
# Train loss: 0.0011799988040424537
# Test loss: 0.024143641378032044
#
# Epoch 54
# ---------
# Train loss: 0.0012158143032255822
# Test loss: 0.006875154416775331
# Save new best model
#
# Epoch 55
# ---------
# Train loss: 0.0011897771304751176
# Test loss: 0.00849964376538992
#
# Epoch 56
# ---------
# Train loss: 0.0012870882515750464
# Test loss: 0.011894032475538552
#
# Epoch 57
# ---------
# Train loss: 0.0012157724770311747
# Test loss: 0.006306862880592234
# Save new best model
#
# Epoch 58
# ---------
# Train loss: 0.0012522595057934296
# Test loss: 0.019452328371698968
#
# Epoch 59
# ---------
# Train loss: 0.001286039762142595
# Test loss: 0.01018407815718092
#
# Epoch 60
# ---------
# Train loss: 0.001209028638597022
# Test loss: 0.006656349723925814
#
# Epoch 61
# ---------
# Train loss: 0.0012378387942707405
# Test loss: 0.008353298355359584
#
# Epoch 62
# ---------
# Train loss: 0.001231106271358928
# Test loss: 0.005060973111540079
# Save new best model
#
# Epoch 63
# ---------
# Train loss: 0.0011805477392514267
# Test loss: 0.005529289061087184
#
# Epoch 64
# ---------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-94-85069e44a80a> in <cell line: 5>()
#       3 param_grid['learning_rate'] = [1e-3,5e-4]
#       4 param_combinations = list(product(*param_grid.values()))
# ----> 5 best_params = grid_search(param_combinations)
#       6 param_grid = copy_from_best(best_params)
#       7 for key, value in param_grid.items():
#
# <ipython-input-92-3854a2c518a3> in grid_search(param_combinations)
#      63         for ix_epoch in range(150):
#      64             print(f"Epoch {ix_epoch}\n---------")
# ---> 65             train_losses.append(train_model(train_loader, model, loss_function, optimizer=optimizer))
#      66             best_val_loss, avg_loss = test_model(val_loader, model, loss_function, best_val_loss)
#      67             val_losses.append(avg_loss)
#
# <ipython-input-83-5673c3488f73> in train_model(data_loader, model, loss_function, optimizer)
#      11
#      12         optimizer.zero_grad()
# ---> 13         loss.backward()
#      14         optimizer.step()
#      15         total_loss += loss.item()
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     520                 inputs=inputs,
#     521             )
# --> 522         torch.autograd.backward(
#     523             self, gradient, retain_graph, create_graph, inputs=inputs
#     524         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     264     # some Python versions print out the first line of a multi-line function
#     265     # calls in the traceback and some print out the last line
# --> 266     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267         tensors,
#     268         grad_tensors_,
#
# KeyboardInterrupt:

# %%
param_grid = copy_from_best(best_params)
param_grid['bidirectional'] = [False]
param_combinations = list(product(*param_grid.values()))
best_params = grid_search(param_combinations)

param_grid = copy_from_best(best_params)
for key, value in param_grid.items():
    print(f"{key}: {value[0]}")

# %%
param_grid = copy_from_best(best_params)
param_grid['num_consecutive_days'] = [30, 60, 90, 120]
param_combinations = list(product(*param_grid.values()))
best_params = grid_search(param_combinations)

param_grid = copy_from_best(best_params)
for key, value in param_grid.items():
    print(f"{key}: {value[0]}")

# %%
param_grid = copy_from_best(best_params)
param_grid['num_lstm_hiddensize'] = [64, 128, 256, 512]
param_combinations = list(product(*param_grid.values()))
best_params = grid_search(param_combinations)

param_grid = copy_from_best(best_params)
for key, value in param_grid.items():
    print(f"{key}: {value[0]}")
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# (0.2, 1e-05, 0.001, 64, 1, 64, 3, False, 90, 1, 1, 32)
# Epoch 0
# ---------
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:83: UserWarning:
#
# dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
# Train loss: 0.16396687308236235
# Test loss: 1.5747916171094403
# Save new best model
#
# Epoch 1
# ---------
# Train loss: 0.004312871356359532
# Test loss: 1.0005638361908495
# Save new best model
#
# Epoch 2
# ---------
# Train loss: 0.003742994045868756
# Test loss: 0.6790850351098925
# Save new best model
#
# Epoch 3
# ---------
# Train loss: 0.0031008300640913205
# Test loss: 0.4729982839198783
# Save new best model
#
# Epoch 4
# ---------
# Train loss: 0.0028939232077156646
# Test loss: 0.4107893002219498
# Save new best model
#
# Epoch 5
# ---------
# Train loss: 0.0028377237664948727
# Test loss: 0.2922214066493325
# Save new best model
#
# Epoch 6
# ---------
# Train loss: 0.0026134442399075677
# Test loss: 0.2650718225049786
# Save new best model
#
# Epoch 7
# ---------
# Train loss: 0.0023226714782199013
# Test loss: 0.1888204971619416
# Save new best model
#
# Epoch 8
# ---------
# Train loss: 0.0023788963852923424
# Test loss: 0.2077919787261635
#
# Epoch 9
# ---------
# Train loss: 0.0022130522467646626
# Test loss: 0.14465234527597204
# Save new best model
#
# Epoch 10
# ---------
# Train loss: 0.0021943649030177884
# Test loss: 0.1548170391470194
#
# Epoch 11
# ---------
# Train loss: 0.0021542130139536194
# Test loss: 0.1691641678335145
#
# Epoch 12
# ---------
# Train loss: 0.0021259141654046553
# Test loss: 0.13487927344976924
# Save new best model
#
# Epoch 13
# ---------
# Train loss: 0.002069376701500357
# Test loss: 0.10826635675039142
# Save new best model
#
# Epoch 14
# ---------
# Train loss: 0.0019555956239327636
# Test loss: 0.14687558758305386
#
# Epoch 15
# ---------
# Train loss: 0.001845690379982003
# Test loss: 0.09328040305990726
# Save new best model
#
# Epoch 16
# ---------
# Train loss: 0.0019322297725481012
# Test loss: 0.09028753959864844
# Save new best model
#
# Epoch 17
# ---------
# Train loss: 0.00177390963630563
# Test loss: 0.08038176462287083
# Save new best model
#
# Epoch 18
# ---------
# Train loss: 0.0017773402918640885
# Test loss: 0.06712116039125249
# Save new best model
#
# Epoch 19
# ---------
# Train loss: 0.0017646733082778332
# Test loss: 0.07214831402234267
#
# Epoch 20
# ---------
# Train loss: 0.0016887725702667189
# Test loss: 0.07141320875962265
#
# Epoch 21
# ---------
# Train loss: 0.0015797898360629446
# Test loss: 0.07443236879771575
#
# Epoch 22
# ---------
# Train loss: 0.001614915948002524
# Test loss: 0.06600965323741548
# Save new best model
#
# Epoch 23
# ---------
# Train loss: 0.0015721690703480084
# Test loss: 0.04571300890529528
# Save new best model
#
# Epoch 24
# ---------
# Train loss: 0.0015069531936821859
# Test loss: 0.06353878986556083
#
# Epoch 25
# ---------
# Train loss: 0.0014645426983347974
# Test loss: 0.04988392761151772
#
# Epoch 26
# ---------
# Train loss: 0.0013975978069919943
# Test loss: 0.0424577564408537
# Save new best model
#
# Epoch 27
# ---------
# Train loss: 0.0014299807449025402
# Test loss: 0.04903133804327808
#
# Epoch 28
# ---------
# Train loss: 0.0014499528087101006
# Test loss: 0.034315302094910294
# Save new best model
#
# Epoch 29
# ---------
# Train loss: 0.0013461773621290171
# Test loss: 0.03347674151882529
# Save new best model
#
# Epoch 30
# ---------
# Train loss: 0.0013889569959100036
# Test loss: 0.030842977183056064
# Save new best model
#
# Epoch 31
# ---------
# Train loss: 0.0013926216263151277
# Test loss: 0.020793420539121144
# Save new best model
#
# Epoch 32
# ---------
# Train loss: 0.001495367515036055
# Test loss: 0.01290499408787582
# Save new best model
#
# Epoch 33
# ---------
# Train loss: 0.0013464238880025673
# Test loss: 0.029718901379965246
#
# Epoch 34
# ---------
# Train loss: 0.0012970660001531454
# Test loss: 0.035372988146264106
#
# Epoch 35
# ---------
# Train loss: 0.0013608356136002489
# Test loss: 0.019629518821602687
#
# Epoch 36
# ---------
# Train loss: 0.001265074995077861
# Test loss: 0.019848530282615684
#
# Epoch 37
# ---------
# Train loss: 0.0012658810899724372
# Test loss: 0.04265799082349986
#
# Epoch 38
# ---------
# Train loss: 0.0013178404436574407
# Test loss: 0.01861356763402
#
# Epoch 39
# ---------
# Train loss: 0.0013521423898055218
# Test loss: 0.00850723717303481
# Save new best model
#
# Epoch 40
# ---------
# Train loss: 0.0013692374024333643
# Test loss: 0.030418951850151643
#
# Epoch 41
# ---------
# Train loss: 0.0012768408217403526
# Test loss: 0.02286271788761951
#
# Epoch 42
# ---------
# Train loss: 0.001259480724383461
# Test loss: 0.007389775491901673
# Save new best model
#
# Epoch 43
# ---------
# Train loss: 0.001274733033853643
# Test loss: 0.011555288307135925
#
# Epoch 44
# ---------
# Train loss: 0.001224721128246822
# Test loss: 0.014426054782234132
#
# Epoch 45
# ---------
# Train loss: 0.001272442472972832
# Test loss: 0.013873450894607231
#
# Epoch 46
# ---------
# Train loss: 0.0012217680604437427
# Test loss: 0.014571550767868757
#
# Epoch 47
# ---------
# Train loss: 0.001217790640610826
# Test loss: 0.010653694771463051
#
# Epoch 48
# ---------
# Train loss: 0.001192331905903918
# Test loss: 0.010629834359860979
#
# Epoch 49
# ---------
# Train loss: 0.0012659381719722954
# Test loss: 0.01929261305485852
#
# Epoch 50
# ---------
# Train loss: 0.001204526735232174
# Test loss: 0.016745295113651082
#
# Epoch 51
# ---------
# Train loss: 0.0011929362653679545
# Test loss: 0.012548616417916492
#
# Epoch 52
# ---------
# Train loss: 0.0012049394746070667
# Test loss: 0.006103148945840076
# Save new best model
#
# Epoch 53
# ---------
# Train loss: 0.0012200788905536155
# Test loss: 0.011967312297201715
#
# Epoch 54
# ---------
# Train loss: 0.0012349342977094854
# Test loss: 0.005520519669516943
# Save new best model
#
# Epoch 55
# ---------
# Train loss: 0.0012506384040123872
# Test loss: 0.014824637008132413
#
# Epoch 56
# ---------
# Train loss: 0.0012106240080151287
# Test loss: 0.02273427211912349
#
# Epoch 57
# ---------
# Train loss: 0.0013514386439290379
# Test loss: 0.017040734412148595
#
# Epoch 58
# ---------
# Train loss: 0.0012057953182750593
# Test loss: 0.005428772696177475
# Save new best model
#
# Epoch 59
# ---------
# Train loss: 0.0013048157432480835
# Test loss: 0.012134069082094356
#
# Epoch 60
# ---------
# Train loss: 0.0012329737512646393
# Test loss: 0.01926815282786265
#
# Epoch 61
# ---------
# Train loss: 0.0012758588390199528
# Test loss: 0.005430192410130985
#
# Epoch 62
# ---------
# Train loss: 0.0012800554545866626
# Test loss: 0.011060182674555108
#
# Epoch 63
# ---------
# Train loss: 0.001212849750440763
# Test loss: 0.014074729042476974
#
# Epoch 64
# ---------
# Train loss: 0.001191123606751658
# Test loss: 0.01294617063831538
#
# Epoch 65
# ---------
# Train loss: 0.0011998303415302577
# Test loss: 0.005189492178033106
# Save new best model
#
# Epoch 66
# ---------
# Train loss: 0.00119336215251561
# Test loss: 0.013436719455057755
#
# Epoch 67
# ---------
# Train loss: 0.0011412748663720013
# Test loss: 0.00701908249175176
#
# Epoch 68
# ---------
# Train loss: 0.0012592879921289896
# Test loss: 0.007755520287901163
#
# Epoch 69
# ---------
# Train loss: 0.0013028674938757303
# Test loss: 0.006361204214044847
#
# Epoch 70
# ---------
# Train loss: 0.0011782788400699746
# Test loss: 0.005301934070303105
#
# Epoch 71
# ---------
# Train loss: 0.0011518864452110364
# Test loss: 0.0066444203548599035
#
# Epoch 72
# ---------
# Train loss: 0.001235240682534265
# Test loss: 0.0056573274050606415
#
# Epoch 73
# ---------
# Train loss: 0.0011823876775451936
# Test loss: 0.005586091137956828
#
# Epoch 74
# ---------
# Train loss: 0.0012039218781865202
# Test loss: 0.0068306170287542045
#
# Epoch 75
# ---------
# Train loss: 0.0011558023803856135
# Test loss: 0.010450981295434758
#
# Epoch 76
# ---------
# Train loss: 0.0012532318462270327
# Test loss: 0.0053482711082324386
#
# Epoch 77
# ---------
# Train loss: 0.001220047667893889
# Test loss: 0.010551189057878219
#
# Epoch 78
# ---------
# Train loss: 0.0011740661706895598
# Test loss: 0.008024669790756889
#
# Epoch 79
# ---------
# Train loss: 0.001200558656907355
# Test loss: 0.007018532836809754
#
# Epoch 80
# ---------
# Train loss: 0.00122400743050328
# Test loss: 0.007062724471325055
#
# Epoch 81
# ---------
# Train loss: 0.0011710293695232981
# Test loss: 0.009547005232889205
#
# Epoch 82
# ---------
# Train loss: 0.0012035383657465928
# Test loss: 0.009922614641254768
#
# Epoch 83
# ---------
# Train loss: 0.0011625978464332048
# Test loss: 0.007936365524074063
#
# Epoch 84
# ---------
# Train loss: 0.0011621334682962287
# Test loss: 0.014249490282963961
#
# Epoch 85
# ---------
# Train loss: 0.001190732763432372
# Test loss: 0.012848650629166514
#
# Epoch 86
# ---------
# Train loss: 0.001207284395340755
# Test loss: 0.008215549140004441
#
# Epoch 87
# ---------
# Train loss: 0.0011605002045173259
# Test loss: 0.006398335593985394
#
# Epoch 88
# ---------
# Train loss: 0.0011648840750680275
# Test loss: 0.007122163675376214
#
# Epoch 89
# ---------
# Train loss: 0.0011479287765518342
# Test loss: 0.006780006136978045
#
# Epoch 90
# ---------
# Train loss: 0.0011484311595972207
# Test loss: 0.005363903561374173
#
# Epoch 91
# ---------
# Train loss: 0.0011571910792788972
# Test loss: 0.01931040914496407
#
# Epoch 92
# ---------
# Train loss: 0.0011757379705217787
# Test loss: 0.005203750260989182
#
# Epoch 93
# ---------
# Train loss: 0.0011970530355146394
# Test loss: 0.007013265436398797
#
# Epoch 94
# ---------
# Train loss: 0.0012400203298555776
# Test loss: 0.009036327013745904
#
# Epoch 95
# ---------
# Train loss: 0.0011484023883484393
# Test loss: 0.008459352276986465
#
# Epoch 96
# ---------
# Train loss: 0.00113353317459358
# Test loss: 0.006696327371173538
#
# Epoch 97
# ---------
# Train loss: 0.001179080594269063
# Test loss: 0.0052297096844995394
#
# Epoch 98
# ---------
# Train loss: 0.001159065540113877
# Test loss: 0.008252480460214429
#
# Epoch 99
# ---------
# Train loss: 0.001176481592870738
# Test loss: 0.005249876558082178
#
# Epoch 100
# ---------
# Train loss: 0.0011190899930361117
# Test loss: 0.005990098477923311
#
# Epoch 101
# ---------
# Train loss: 0.001115130444715408
# Test loss: 0.006094819385907613
#
# Epoch 102
# ---------
# Train loss: 0.0011607512546282623
# Test loss: 0.01123381408979185
#
# Epoch 103
# ---------
# Train loss: 0.0012060703684842484
# Test loss: 0.005274716197163798
#
# Epoch 104
# ---------
# Train loss: 0.0011267330330390964
# Test loss: 0.0061242100928211585
#
# Epoch 105
# ---------
# Train loss: 0.0011856612850791744
# Test loss: 0.005635359193547629
#
# Epoch 106
# ---------
# Train loss: 0.0012346592527812332
# Test loss: 0.008169195323716849
#
# Epoch 107
# ---------
# Train loss: 0.0011893489345018151
# Test loss: 0.005450101001770236
#
# Epoch 108
# ---------
# Train loss: 0.001174423976349757
# Test loss: 0.0062744089955231175
#
# Epoch 109
# ---------
# Train loss: 0.0011267026014637291
# Test loss: 0.013599924044683576
#
# Epoch 110
# ---------
# Train loss: 0.001203336552979665
# Test loss: 0.0065050872071878985
#
# Epoch 111
# ---------
# Train loss: 0.0011419941637864067
# Test loss: 0.005982762842904776
#
# Epoch 112
# ---------
# Train loss: 0.0011340833645531788
# Test loss: 0.005250882153632119
#
# Epoch 113
# ---------
# Train loss: 0.0011471891583266457
# Test loss: 0.0070302965614246204
#
# Epoch 114
# ---------
# Train loss: 0.0011595541882636626
# Test loss: 0.03062208165647462
#
# Epoch 115
# ---------
# Train loss: 0.0011392753428569244
# Test loss: 0.028413856838596985
#
# Epoch 116
# ---------
# Train loss: 0.0011928548889456228
# Test loss: 0.026294301031157374
#
# Epoch 117
# ---------
# Train loss: 0.0011422528125788836
# Test loss: 0.009478910418692976
#
# Epoch 118
# ---------
# Train loss: 0.0011768327669649866
# Test loss: 0.010523379576625302
#
# Epoch 119
# ---------
# Train loss: 0.0011625440153781505
# Test loss: 0.009335066089988686
#
# Epoch 120
# ---------
# Train loss: 0.001132726778098825
# Test loss: 0.005934673725278117
#
# Epoch 121
# ---------
# Train loss: 0.0011141207695829743
# Test loss: 0.007087735706591047
#
# Epoch 122
# ---------
# Train loss: 0.001125362187233423
# Test loss: 0.00929280171112623
#
# Epoch 123
# ---------
# Train loss: 0.001143073469950562
# Test loss: 0.010733611226896755
#
# Epoch 124
# ---------
# Train loss: 0.0011051004600425762
# Test loss: 0.008252724685007706
#
# Epoch 125
# ---------
# Train loss: 0.0011227405946908308
# Test loss: 0.021898023929679766
#
# Epoch 126
# ---------
# Train loss: 0.001145443746692411
# Test loss: 0.014220710218069144
#
# Epoch 127
# ---------
# Train loss: 0.001114122100613801
# Test loss: 0.03810295186121948
#
# Epoch 128
# ---------
# Train loss: 0.0011682811673381366
# Test loss: 0.015390965301776305
#
# Epoch 129
# ---------
# Train loss: 0.0011165340915941934
# Test loss: 0.016200642436160706
#
# Epoch 130
# ---------
# Train loss: 0.0011152135890780859
# Test loss: 0.018528738291934133
#
# Epoch 131
# ---------
# Train loss: 0.0011147216605276035
# Test loss: 0.04717008912120946
#
# Epoch 132
# ---------
# Train loss: 0.0011374160373722384
# Test loss: 0.04026078182505444
#
# Epoch 133
# ---------
# Train loss: 0.001111965673889274
# Test loss: 0.029404082175460644
#
# Epoch 134
# ---------
# Train loss: 0.0011603065542012995
# Test loss: 0.020434810328879394
#
# Epoch 135
# ---------
# Train loss: 0.0010899701310629626
# Test loss: 0.01189512743439991
#
# Epoch 136
# ---------
# Train loss: 0.0010797361538871268
# Test loss: 0.047759498324012384
#
# Epoch 137
# ---------
# Train loss: 0.0010740614180254088
# Test loss: 0.03169949012226425
#
# Epoch 138
# ---------
# Train loss: 0.0011571360785549792
# Test loss: 0.07595587796822656
#
# Epoch 139
# ---------
# Train loss: 0.0011014450179983773
# Test loss: 0.06639996165176854
#
# Epoch 140
# ---------
# Train loss: 0.001165034443528707
# Test loss: 0.04490833164891228
#
# Epoch 141
# ---------
# Train loss: 0.001186534432147915
# Test loss: 0.03556732492870651
#
# Epoch 142
# ---------
# Train loss: 0.0010867845771680286
# Test loss: 0.07473420575843193
#
# Epoch 143
# ---------
# Train loss: 0.00112188294036558
# Test loss: 0.05639447012799792
#
# Epoch 144
# ---------
# Train loss: 0.001101175976087219
# Test loss: 0.05489525641314685
#
# Epoch 145
# ---------
# Train loss: 0.0010790923289248659
# Test loss: 0.0671934146375861
#
# Epoch 146
# ---------
# Train loss: 0.001136771956929982
# Test loss: 0.08818190239253454
#
# Epoch 147
# ---------
# Train loss: 0.0010872319508052897
# Test loss: 0.07623789549688809
#
# Epoch 148
# ---------
# Train loss: 0.0010826766529428442
# Test loss: 0.08818370514200069
#
# Epoch 149
# ---------
# Train loss: 0.0010931233107018465
# Test loss: 0.1172250998497475
#
# (0.2, 1e-05, 0.001, 128, 1, 64, 3, False, 90, 1, 1, 32)
# Epoch 0
# ---------
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:83: UserWarning:
#
# dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
# Train loss: 0.14172541201602848
# Test loss: 1.1260406663641334
#
# Epoch 1
# ---------
# Train loss: 0.0038750212641447904
# Test loss: 0.661870650772471
#
# Epoch 2
# ---------
# Train loss: 0.003547823920774634
# Test loss: 0.43697026040172204
#
# Epoch 3
# ---------
# Train loss: 0.0032116168445246594
# Test loss: 0.2340796716598561
#
# Epoch 4
# ---------
# Train loss: 0.002814066073399097
# Test loss: 0.25248742138501257
#
# Epoch 5
# ---------
# Train loss: 0.002791512179218473
# Test loss: 0.15929233306087554
#
# Epoch 6
# ---------
# Train loss: 0.002623036744133119
# Test loss: 0.18043516797479242
#
# Epoch 7
# ---------
# Train loss: 0.0024178749492068984
# Test loss: 0.08563409265480004
#
# Epoch 8
# ---------
# Train loss: 0.0023611515897491407
# Test loss: 0.11572529797558673
#
# Epoch 9
# ---------
# Train loss: 0.0021855549942213864
# Test loss: 0.07821269641863182
#
# Epoch 10
# ---------
# Train loss: 0.002331743653837381
# Test loss: 0.11362971848575398
#
# Epoch 11
# ---------
# Train loss: 0.002080776918333985
# Test loss: 0.037649566074833274
#
# Epoch 12
# ---------
# Train loss: 0.0022157152679057853
# Test loss: 0.07026134160696529
#
# Epoch 13
# ---------
# Train loss: 0.0018696604383876547
# Test loss: 0.06694381358101964
#
# Epoch 14
# ---------
# Train loss: 0.0022741348380335576
# Test loss: 0.0739649246679619
#
# Epoch 15
# ---------
# Train loss: 0.001888221876382182
# Test loss: 0.060029210639186203
#
# Epoch 16
# ---------
# Train loss: 0.0019093150706706388
# Test loss: 0.023444049467798322
#
# Epoch 17
# ---------
# Train loss: 0.0016566837397066034
# Test loss: 0.029439895413815975
#
# Epoch 18
# ---------
# Train loss: 0.0016359824742633669
# Test loss: 0.06994924071477726
#
# Epoch 19
# ---------
# Train loss: 0.0016697674798178336
# Test loss: 0.07149221008876339
#
# Epoch 20
# ---------
# Train loss: 0.001802424310177054
# Test loss: 0.06555677496362478
#
# Epoch 21
# ---------
# Train loss: 0.0015279460464127273
# Test loss: 0.028275007469346747
#
# Epoch 22
# ---------
# Train loss: 0.0015953313563987913
# Test loss: 0.022014821661286987
#
# Epoch 23
# ---------
# Train loss: 0.0015286351647979069
# Test loss: 0.04128804022911936
#
# Epoch 24
# ---------
# Train loss: 0.0015333221221695685
# Test loss: 0.02256532594037708
#
# Epoch 25
# ---------
# Train loss: 0.0014847562377971987
# Test loss: 0.024753958961809985
#
# Epoch 26
# ---------
# Train loss: 0.0014729306806862774
# Test loss: 0.032109155668877065
#
# Epoch 27
# ---------
# Train loss: 0.0013269294882305867
# Test loss: 0.012689172683167271
#
# Epoch 28
# ---------
# Train loss: 0.0013415380305941067
# Test loss: 0.01954956428380683
#
# Epoch 29
# ---------
# Train loss: 0.0014818199898957486
# Test loss: 0.045829626789782196
#
# Epoch 30
# ---------
# Train loss: 0.0013905730353848589
# Test loss: 0.008519527924363501
#
# Epoch 31
# ---------
# Train loss: 0.001493467665803168
# Test loss: 0.0244496873638127
#
# Epoch 32
# ---------
# Train loss: 0.001280903194480831
# Test loss: 0.015139498966163956
#
# Epoch 33
# ---------
# Train loss: 0.001547524426226324
# Test loss: 0.026356284855864942
#
# Epoch 34
# ---------
# Train loss: 0.0012388555121780824
# Test loss: 0.022671359940432012
#
# Epoch 35
# ---------
# Train loss: 0.0013603760662297118
# Test loss: 0.006791658903239295
#
# Epoch 36
# ---------
# Train loss: 0.0012982963664633703
# Test loss: 0.009703149931738153
#
# Epoch 37
# ---------
# Train loss: 0.001366976925524913
# Test loss: 0.010127772286068648
#
# Epoch 38
# ---------
# Train loss: 0.001326437734185733
# Test loss: 0.00588951914687641
#
# Epoch 39
# ---------
# Train loss: 0.0013238880055723712
# Test loss: 0.012204530590679497
#
# Epoch 40
# ---------
# Train loss: 0.0012348944576167982
# Test loss: 0.029921273497166112
#
# Epoch 41
# ---------
# Train loss: 0.0012284191851053507
# Test loss: 0.00538004761619959
#
# Epoch 42
# ---------
# Train loss: 0.0012661682978373833
# Test loss: 0.005927462756517343
#
# Epoch 43
# ---------
# Train loss: 0.0012253572466790737
# Test loss: 0.01216708192077931
#
# Epoch 44
# ---------
# Train loss: 0.00127023227081912
# Test loss: 0.01863246809807606
#
# Epoch 45
# ---------
# Train loss: 0.0012308800303857893
# Test loss: 0.007873544265748933
#
# Epoch 46
# ---------
# Train loss: 0.0013821447348398637
# Test loss: 0.005804620974231511
#
# Epoch 47
# ---------
# Train loss: 0.0012806922578977632
# Test loss: 0.011385437479475513
#
# Epoch 48
# ---------
# Train loss: 0.0012227948473375891
# Test loss: 0.007539265701780096
#
# Epoch 49
# ---------
# Train loss: 0.0012613948422386461
# Test loss: 0.008142956285155378
#
# Epoch 50
# ---------
# Train loss: 0.0012562951944287747
# Test loss: 0.005863921127456706
#
# Epoch 51
# ---------
# Train loss: 0.001288634019147139
# Test loss: 0.008166718413121998
#
# Epoch 52
# ---------
# Train loss: 0.0012985231989014504
# Test loss: 0.016372489189961925
#
# Epoch 53
# ---------
# Train loss: 0.0011707925964841589
# Test loss: 0.007769623873173259
#
# Epoch 54
# ---------
# Train loss: 0.0012165538562018605
# Test loss: 0.016362408496206626
#
# Epoch 55
# ---------
# Train loss: 0.0012437596604051519
# Test loss: 0.025603217800380662
#
# Epoch 56
# ---------
# Train loss: 0.0012001684839150026
# Test loss: 0.012079221443855204
#
# Epoch 57
# ---------
# Train loss: 0.0012679595514078579
# Test loss: 0.005677883353200741
#
# Epoch 58
# ---------
# Train loss: 0.0012324456228300059
# Test loss: 0.00622390877106227
#
# Epoch 59
# ---------
# Train loss: 0.001152132639911161
# Test loss: 0.015670616892748512
#
# Epoch 60
# ---------
# Train loss: 0.0013102326523831806
# Test loss: 0.008954272750997916
#
# Epoch 61
# ---------
# Train loss: 0.0012742869915992714
# Test loss: 0.023720786877674982
#
# Epoch 62
# ---------
# Train loss: 0.0012951123332435777
# Test loss: 0.006538457630085759
#
# Epoch 63
# ---------
# Train loss: 0.001258229448379303
# Test loss: 0.007286104315426201
#
# Epoch 64
# ---------
# Train loss: 0.001253991374875524
# Test loss: 0.012906960168038495
#
# Epoch 65
# ---------
# Train loss: 0.0011887385410391876
# Test loss: 0.00855219860386569
#
# Epoch 66
# ---------
# Train loss: 0.0012105170364168684
# Test loss: 0.01839037620811723
#
# Epoch 67
# ---------
# Train loss: 0.0013834925496578967
# Test loss: 0.0107526706851786
#
# Epoch 68
# ---------
# Train loss: 0.00126763436456977
# Test loss: 0.025297450891230255
#
# Epoch 69
# ---------
# Train loss: 0.0012445612906782527
# Test loss: 0.015358005999587476
#
# Epoch 70
# ---------
# Train loss: 0.0012542234286346712
# Test loss: 0.006409350433386862
#
# Epoch 71
# ---------
# Train loss: 0.0012282203137029654
# Test loss: 0.021883909445023164
#
# Epoch 72
# ---------
# Train loss: 0.0012517097437070802
# Test loss: 0.009861494792858139
#
# Epoch 73
# ---------
# Train loss: 0.0012155654875377583
# Test loss: 0.035397773201111704
#
# Epoch 74
# ---------
# Train loss: 0.0012812504785195474
# Test loss: 0.008033032514504157
#
# Epoch 75
# ---------
# Train loss: 0.0012196411365537993
# Test loss: 0.030437210807576776
#
# Epoch 76
# ---------
# Train loss: 0.0012495496916779948
# Test loss: 0.0054147781629581004
#
# Epoch 77
# ---------
# Train loss: 0.001196123897018204
# Test loss: 0.013650060747750103
#
# Epoch 78
# ---------
# Train loss: 0.00124975571464259
# Test loss: 0.016647843411192298
#
# Epoch 79
# ---------
# Train loss: 0.001191054951989152
# Test loss: 0.008551145831006579
#
# Epoch 80
# ---------
# Train loss: 0.0011559967282547376
# Test loss: 0.0058483518223511055
#
# Epoch 81
# ---------
# Train loss: 0.0011465247807791457
# Test loss: 0.008580701789469458
#
# Epoch 82
# ---------
# Train loss: 0.001178200304087612
# Test loss: 0.005850884306710213
#
# Epoch 83
# ---------
# Train loss: 0.0012605650288957891
# Test loss: 0.012295091670239344
#
# Epoch 84
# ---------
# Train loss: 0.0012188257551902244
# Test loss: 0.010597795306239277
#
# Epoch 85
# ---------
# Train loss: 0.0012008374037724289
# Test loss: 0.024322155048139393
#
# Epoch 86
# ---------
# Train loss: 0.001167636820971365
# Test loss: 0.01047151445527561
#
# Epoch 87
# ---------
# Train loss: 0.0013251096761744139
# Test loss: 0.0074881123000523075
#
# Epoch 88
# ---------
# Train loss: 0.0012998503169059873
# Test loss: 0.027516009722603485
#
# Epoch 89
# ---------
# Train loss: 0.0012590262004748857
# Test loss: 0.020783534389920533
#
# Epoch 90
# ---------
# Train loss: 0.0011733102547887323
# Test loss: 0.008753262110985816
#
# Epoch 91
# ---------
# Train loss: 0.0012538113918591051
# Test loss: 0.005959299625828862
#
# Epoch 92
# ---------
# Train loss: 0.001225131363636108
# Test loss: 0.006302130699623376
#
# Epoch 93
# ---------
# Train loss: 0.0012340916491079806
# Test loss: 0.00804892803716939
#
# Epoch 94
# ---------
# Train loss: 0.0012105785872629513
# Test loss: 0.0070224308292381465
#
# Epoch 95
# ---------
# Train loss: 0.0011258097656536847
# Test loss: 0.006642655163886957
#
# Epoch 96
# ---------
# Train loss: 0.001198659440448072
# Test loss: 0.010299326037056744
#
# Epoch 97
# ---------
# Train loss: 0.0011642395899886446
# Test loss: 0.005371208855649456
#
# Epoch 98
# ---------
# Train loss: 0.0011760960126505984
# Test loss: 0.007382224255707115
#
# Epoch 99
# ---------
# Train loss: 0.0012934157446931837
# Test loss: 0.007126913085812703
#
# Epoch 100
# ---------
# Train loss: 0.001178128089973583
# Test loss: 0.010107673588208854
#
# Epoch 101
# ---------
# Train loss: 0.001179933431558311
# Test loss: 0.012182372389361262
#
# Epoch 102
# ---------
# Train loss: 0.0011882258460841953
# Test loss: 0.00810795690631494
#
# Epoch 103
# ---------
# Train loss: 0.0012246496100429326
# Test loss: 0.006228031837963499
#
# Epoch 104
# ---------
# Train loss: 0.0011903099638725361
# Test loss: 0.005142740315932315
# Save new best model
#
# Epoch 105
# ---------
# Train loss: 0.0011915486754714361
# Test loss: 0.006375741300871596
#
# Epoch 106
# ---------
# Train loss: 0.001231917156767468
# Test loss: 0.009235357108991593
#
# Epoch 107
# ---------
# Train loss: 0.001222445729757554
# Test loss: 0.010889451514231041
#
# Epoch 108
# ---------
# Train loss: 0.0011760737121925735
# Test loss: 0.008241461793659255
#
# Epoch 109
# ---------
# Train loss: 0.0011965138281436426
# Test loss: 0.010362835513660684
#
# Epoch 110
# ---------
# Train loss: 0.0012196300972831405
# Test loss: 0.02476263535209
#
# Epoch 111
# ---------
# Train loss: 0.0012472071438453221
# Test loss: 0.007603077552630566
#
# Epoch 112
# ---------
# Train loss: 0.001138599050107352
# Test loss: 0.017633429961279035
#
# Epoch 113
# ---------
# Train loss: 0.0012969210667154497
# Test loss: 0.012365546339424327
#
# Epoch 114
# ---------
# Train loss: 0.0012433378555391345
# Test loss: 0.029091408621752635
#
# Epoch 115
# ---------
# Train loss: 0.0013397500839463674
# Test loss: 0.009512507618637756
#
# Epoch 116
# ---------
# Train loss: 0.0011818180801422004
# Test loss: 0.008766906961682253
#
# Epoch 117
# ---------
# Train loss: 0.0011601946849447314
# Test loss: 0.005766524380305782
#
# Epoch 118
# ---------
# Train loss: 0.0011505505500545336
# Test loss: 0.032929623615927994
#
# Epoch 119
# ---------
# Train loss: 0.001139712468307886
# Test loss: 0.01676770871563349
#
# Epoch 120
# ---------
# Train loss: 0.0012069101104580408
# Test loss: 0.024070462153758854
#
# Epoch 121
# ---------
# Train loss: 0.0011732386804895565
# Test loss: 0.04695034529140685
#
# Epoch 122
# ---------
# Train loss: 0.0012516860447395893
# Test loss: 0.016841437347466126
#
# Epoch 123
# ---------
# Train loss: 0.0011906352817952152
# Test loss: 0.006465134647442028
#
# Epoch 124
# ---------
# Train loss: 0.0011788710168818192
# Test loss: 0.011636658207862638
#
# Epoch 125
# ---------
# Train loss: 0.0011798770297431357
# Test loss: 0.019883987988578156
#
# Epoch 126
# ---------
# Train loss: 0.0012301585677872231
# Test loss: 0.017816802763263695
#
# Epoch 127
# ---------
# Train loss: 0.0011318943215883337
# Test loss: 0.01823537505697459
#
# Epoch 128
# ---------
# Train loss: 0.0011530149905968669
# Test loss: 0.02810977410990745
#
# Epoch 129
# ---------
# Train loss: 0.001114570629837427
# Test loss: 0.012782756355591118
#
# Epoch 130
# ---------
# Train loss: 0.0011924382752406546
# Test loss: 0.004710365828941576
# Save new best model
#
# Epoch 131
# ---------
# Train loss: 0.0011463628261774448
# Test loss: 0.006706216547172517
#
# Epoch 132
# ---------
# Train loss: 0.001157825574703184
# Test loss: 0.005801435458124615
#
# Epoch 133
# ---------
# Train loss: 0.0012602699519653293
# Test loss: 0.00573108930257149
#
# Epoch 134
# ---------
# Train loss: 0.0011552299291642772
# Test loss: 0.007816716737579554
#
# Epoch 135
# ---------
# Train loss: 0.0011581980638326176
# Test loss: 0.005183329660212621
#
# Epoch 136
# ---------
# Train loss: 0.001192773305979978
# Test loss: 0.004913838842185214
#
# Epoch 137
# ---------
# Train loss: 0.001185070282160943
# Test loss: 0.028321990539552644
#
# Epoch 138
# ---------
# Train loss: 0.0011487329456647257
# Test loss: 0.006495532943517901
#
# Epoch 139
# ---------
# Train loss: 0.0011708241390513121
# Test loss: 0.021862270557903685
#
# Epoch 140
# ---------
# Train loss: 0.0011120800174408473
# Test loss: 0.02404181400197558
#
# Epoch 141
# ---------
# Train loss: 0.0011161961099846408
# Test loss: 0.008827581143123098
#
# Epoch 142
# ---------
# Train loss: 0.001140809016144504
# Test loss: 0.023060506384354085
#
# Epoch 143
# ---------
# Train loss: 0.001136324450917234
# Test loss: 0.016715210178517736
#
# Epoch 144
# ---------
# Train loss: 0.0011446076054961586
# Test loss: 0.011452215607278049
#
# Epoch 145
# ---------
# Train loss: 0.001109267600000866
# Test loss: 0.026056374990730546
#
# Epoch 146
# ---------
# Train loss: 0.001165351779491175
# Test loss: 0.034708563340245746
#
# Epoch 147
# ---------
# Train loss: 0.0011402701709284297
# Test loss: 0.2722990771289915
#
# Epoch 148
# ---------
# Train loss: 0.0011363686338177836
# Test loss: 0.19152089417912066
#
# Epoch 149
# ---------
# Train loss: 0.001119986799523993
# Test loss: 1.4252770337625407
#
# (0.2, 1e-05, 0.001, 256, 1, 64, 3, False, 90, 1, 1, 32)
# Epoch 0
# ---------
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:83: UserWarning:
#
# dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
# Train loss: 0.08371626505170078
# Test loss: 0.6399741705972701
#
# Epoch 1
# ---------
# Train loss: 0.0035300645897457855
# Test loss: 0.235271567304153
#
# Epoch 2
# ---------
# Train loss: 0.00318879552885905
# Test loss: 0.10672104096738622
#
# Epoch 3
# ---------
# Train loss: 0.003083961083546221
# Test loss: 0.15637250908184797
#
# Epoch 4
# ---------
# Train loss: 0.002975456318968246
# Test loss: 0.03567512266454287
#
# Epoch 5
# ---------
# Train loss: 0.0027119981720217412
# Test loss: 0.08863268070854247
#
# Epoch 6
# ---------
# Train loss: 0.002908724101988839
# Test loss: 0.03941794886486605
#
# Epoch 7
# ---------
# Train loss: 0.002391365856672036
# Test loss: 0.043660296098096296
#
# Epoch 8
# ---------
# Train loss: 0.002272813346221923
# Test loss: 0.06437795329838991
#
# Epoch 9
# ---------
# Train loss: 0.002410070061863911
# Test loss: 0.06295334314927459
#
# Epoch 10
# ---------
# Train loss: 0.002229449947574927
# Test loss: 0.032095143615151756
#
# Epoch 11
# ---------
# Train loss: 0.0020054444340207884
# Test loss: 0.009401675051776692
#
# Epoch 12
# ---------
# Train loss: 0.0019242591426459953
# Test loss: 0.01435735888662748
#
# Epoch 13
# ---------
# Train loss: 0.002098724219268338
# Test loss: 0.04004964302293956
#
# Epoch 14
# ---------
# Train loss: 0.0018099871127971359
# Test loss: 0.0085891823109705
#
# Epoch 15
# ---------
# Train loss: 0.0017997869224693145
# Test loss: 0.019071121772867627
#
# Epoch 16
# ---------
# Train loss: 0.0017109285540608389
# Test loss: 0.006735980787198059
#
# Epoch 17
# ---------
# Train loss: 0.001811102694069456
# Test loss: 0.010159452445805073
#
# Epoch 18
# ---------
# Train loss: 0.001574097462458491
# Test loss: 0.011424736469052732
#
# Epoch 19
# ---------
# Train loss: 0.0015907809410559675
# Test loss: 0.009884888306260109
#
# Epoch 20
# ---------
# Train loss: 0.0014422406895919853
# Test loss: 0.02787071478087455
#
# Epoch 21
# ---------
# Train loss: 0.0014852292946260046
# Test loss: 0.009371301013743505
#
# Epoch 22
# ---------
# Train loss: 0.0014519753775300247
# Test loss: 0.008121079255943187
#
# Epoch 23
# ---------
# Train loss: 0.0014230946744059874
# Test loss: 0.008968503214418888
#
# Epoch 24
# ---------
# Train loss: 0.0014016135152609599
# Test loss: 0.012912293605040759
#
# Epoch 25
# ---------
# Train loss: 0.0014322797531701413
# Test loss: 0.008510568470228463
#
# Epoch 26
# ---------
# Train loss: 0.001408684950635483
# Test loss: 0.0066147774195997044
#
# Epoch 27
# ---------
# Train loss: 0.001774830443478535
# Test loss: 0.022357604990247637
#
# Epoch 28
# ---------
# Train loss: 0.0013149690111599593
# Test loss: 0.009598826232831925
#
# Epoch 29
# ---------
# Train loss: 0.0014157318075904773
# Test loss: 0.007820794839062728
#
# Epoch 30
# ---------
# Train loss: 0.0014096708903032836
# Test loss: 0.011796790000516921
#
# Epoch 31
# ---------
# Train loss: 0.0012875532033391327
# Test loss: 0.005417664346168749
#
# Epoch 32
# ---------
# Train loss: 0.0012801717307264616
# Test loss: 0.010448723944136873
#
# Epoch 33
# ---------
# Train loss: 0.001297266345993135
# Test loss: 0.006713026174111292
#
# Epoch 34
# ---------
# Train loss: 0.0013052288693049172
# Test loss: 0.006350169773213565
#
# Epoch 35
# ---------
# Train loss: 0.0013921639207007002
# Test loss: 0.036481859104242176
#
# Epoch 36
# ---------
# Train loss: 0.0014057609840810688
# Test loss: 0.02279723813990131
#
# Epoch 37
# ---------
# Train loss: 0.0013002283169865428
# Test loss: 0.005691377620678395
#
# Epoch 38
# ---------
# Train loss: 0.0012996371017746447
# Test loss: 0.015310651069739833
#
# Epoch 39
# ---------
# Train loss: 0.001362282094158863
# Test loss: 0.00959978012542706
#
# Epoch 40
# ---------
# Train loss: 0.0012603321632805972
# Test loss: 0.005490600975463167
#
# Epoch 41
# ---------
# Train loss: 0.0013245362682820058
# Test loss: 0.005808222311316058
#
# Epoch 42
# ---------
# Train loss: 0.0012247217444734902
# Test loss: 0.006325244830804877
#
# Epoch 43
# ---------
# Train loss: 0.0012853942281517742
# Test loss: 0.008327600662596524
#
# Epoch 44
# ---------
# Train loss: 0.00143419268856486
# Test loss: 0.005583210120676085
#
# Epoch 45
# ---------
# Train loss: 0.0012911783105077883
# Test loss: 0.006254649983020499
#
# Epoch 46
# ---------
# Train loss: 0.0012655335862467427
# Test loss: 0.008349787283805199
#
# Epoch 47
# ---------
# Train loss: 0.0013044430884145831
# Test loss: 0.0257464645546861
#
# Epoch 48
# ---------
# Train loss: 0.001321042531344574
# Test loss: 0.007927577491500415
#
# Epoch 49
# ---------
# Train loss: 0.0013286116990193183
# Test loss: 0.03001145733287558
#
# Epoch 50
# ---------
# Train loss: 0.0012886899609340266
# Test loss: 0.010611728401272558
#
# Epoch 51
# ---------
# Train loss: 0.0012450708401898268
# Test loss: 0.04453706200001761
#
# Epoch 52
# ---------
# Train loss: 0.0013136560892528524
# Test loss: 0.019092336398898624
#
# Epoch 53
# ---------
# Train loss: 0.0012452434002038753
# Test loss: 0.011770718105253763
#
# Epoch 54
# ---------
# Train loss: 0.001338039263388172
# Test loss: 0.016848318322445266
#
# Epoch 55
# ---------
# Train loss: 0.0012475401219431191
# Test loss: 0.036137670394964516
#
# Epoch 56
# ---------
# Train loss: 0.0013008260303327152
# Test loss: 0.018381273577688262
#
# Epoch 57
# ---------
# Train loss: 0.0012678104150484527
# Test loss: 0.008372908196179196
#
# Epoch 58
# ---------
# Train loss: 0.0013579919456876064
# Test loss: 0.012614434395800345
#
# Epoch 59
# ---------
# Train loss: 0.0013398130989028892
# Test loss: 0.011920779186766595
#
# Epoch 60
# ---------
# Train loss: 0.0012092195759196916
# Test loss: 0.009938141127349809
#
# Epoch 61
# ---------
# Train loss: 0.001306248139195715
# Test loss: 0.034239762753713876
#
# Epoch 62
# ---------
# Train loss: 0.001233326650230259
# Test loss: 0.0072336267767241225
#
# Epoch 63
# ---------
# Train loss: 0.0012103249715554767
# Test loss: 0.006245527896680869
#
# Epoch 64
# ---------
# Train loss: 0.0012454414543519247
# Test loss: 0.007293000671779737
#
# Epoch 65
# ---------
# Train loss: 0.0012107384771356479
# Test loss: 0.005108318247948773
#
# Epoch 66
# ---------
# Train loss: 0.0012980591697757313
# Test loss: 0.01389932342863176
#
# Epoch 67
# ---------
# Train loss: 0.0013290009970190904
# Test loss: 0.006223168718861416
#
# Epoch 68
# ---------
# Train loss: 0.0012898300687553392
# Test loss: 0.007895954782725312
#
# Epoch 69
# ---------
# Train loss: 0.0012047993636036653
# Test loss: 0.03028884466039017
#
# Epoch 70
# ---------
# Train loss: 0.001305768480139499
# Test loss: 0.008247977690189146
#
# Epoch 71
# ---------
# Train loss: 0.001354314127257244
# Test loss: 0.017935519863385707
#
# Epoch 72
# ---------
# Train loss: 0.0011916466974071227
# Test loss: 0.006171997825731523
#
# Epoch 73
# ---------
# Train loss: 0.001318995260179133
# Test loss: 0.019709772459464148
#
# Epoch 74
# ---------
# Train loss: 0.0012875296707798337
# Test loss: 0.006282736794673838
#
# Epoch 75
# ---------
# Train loss: 0.0013682888318491619
# Test loss: 0.016649346856866032
#
# Epoch 76
# ---------
# Train loss: 0.0011759331175726989
# Test loss: 0.01316546686575748
#
# Epoch 77
# ---------
# Train loss: 0.0012275228032048026
# Test loss: 0.008419501391472295
#
# Epoch 78
# ---------
# Train loss: 0.0014100366036385117
# Test loss: 0.005718379441532306
#
# Epoch 79
# ---------
# Train loss: 0.0013219950138121813
# Test loss: 0.009026610030559823
#
# Epoch 80
# ---------
# Train loss: 0.001276199878644078
# Test loss: 0.010249935352476314
#
# Epoch 81
# ---------
# Train loss: 0.001250471451179868
# Test loss: 0.006701189297018573
#
# Epoch 82
# ---------
# Train loss: 0.0011935646616620943
# Test loss: 0.008278683861135505
#
# Epoch 83
# ---------
# Train loss: 0.001184376734947305
# Test loss: 0.010320399713236839
#
# Epoch 84
# ---------
# Train loss: 0.0012085524590915039
# Test loss: 0.005617690956569277
#
# Epoch 85
# ---------
# Train loss: 0.0013001239518240664
# Test loss: 0.02326870895922184
#
# Epoch 86
# ---------
# Train loss: 0.0013017416520949242
# Test loss: 0.010060856453492306
#
# Epoch 87
# ---------
# Train loss: 0.0012385591896506207
# Test loss: 0.012367143208393827
#
# Epoch 88
# ---------
# Train loss: 0.001293548061268314
# Test loss: 0.016465138702187687
#
# Epoch 89
# ---------
# Train loss: 0.001307852079691891
# Test loss: 0.006404303494491614
#
# Epoch 90
# ---------
# Train loss: 0.0012390454188965622
# Test loss: 0.0055702911777189
#
# Epoch 91
# ---------
# Train loss: 0.001221534793359986
# Test loss: 0.006336939055472612
#
# Epoch 92
# ---------
# Train loss: 0.0011380690850801916
# Test loss: 0.00555374487885274
#
# Epoch 93
# ---------
# Train loss: 0.0012301018519323289
# Test loss: 0.007983844916452654
#
# Epoch 94
# ---------
# Train loss: 0.001224103691657224
# Test loss: 0.011659925119602121
#
# Epoch 95
# ---------
# Train loss: 0.001277541114588178
# Test loss: 0.009964158234652132
#
# Epoch 96
# ---------
# Train loss: 0.0012599130415999811
# Test loss: 0.021656267839716747
#
# Epoch 97
# ---------
# Train loss: 0.0012061337021746553
# Test loss: 0.009867237269645557
#
# Epoch 98
# ---------
# Train loss: 0.0012469496822074776
# Test loss: 0.0055828430922701955
#
# Epoch 99
# ---------
# Train loss: 0.001235562945141517
# Test loss: 0.012481865516747348
#
# Epoch 100
# ---------
# Train loss: 0.0011791555943707335
# Test loss: 0.024538612982723862
#
# Epoch 101
# ---------
# Train loss: 0.0012051122717938625
# Test loss: 0.010059828666271642
#
# Epoch 102
# ---------
# Train loss: 0.0011770447200697457
# Test loss: 0.010473406611708924
#
# Epoch 103
# ---------
# Train loss: 0.0011980628018312517
# Test loss: 0.004629178089089692
# Save new best model
#
# Epoch 104
# ---------
# Train loss: 0.0012050893781105838
# Test loss: 0.026914677146123722
#
# Epoch 105
# ---------
# Train loss: 0.0012350686651658297
# Test loss: 0.009565863801981322
#
# Epoch 106
# ---------
# Train loss: 0.0012247599877281896
# Test loss: 0.007545820262748748
#
# Epoch 107
# ---------
# Train loss: 0.001184343755378523
# Test loss: 0.0063714851858094335
#
# Epoch 108
# ---------
# Train loss: 0.0011636746369936923
# Test loss: 0.03083162844995968
#
# Epoch 109
# ---------
# Train loss: 0.0012256230249711793
# Test loss: 0.011204461508896202
#
# Epoch 110
# ---------
# Train loss: 0.001151714135748109
# Test loss: 0.006351836695102975
#
# Epoch 111
# ---------
# Train loss: 0.0012132161397359245
# Test loss: 0.030379787131096236
#
# Epoch 112
# ---------
# Train loss: 0.0011654602074544996
# Test loss: 0.022281430239672773
#
# Epoch 113
# ---------
# Train loss: 0.0011615572263009757
# Test loss: 0.009979749302146956
#
# Epoch 114
# ---------
# Train loss: 0.001185463705511328
# Test loss: 0.024547972716391087
#
# Epoch 115
# ---------
# Train loss: 0.0012152861344211193
# Test loss: 0.027411893184762448
#
# Epoch 116
# ---------
# Train loss: 0.0011643297083566958
# Test loss: 0.01666608358209487
#
# Epoch 117
# ---------
# Train loss: 0.0011825576563546014
# Test loss: 0.0651353451248724
#
# Epoch 118
# ---------
# Train loss: 0.0012239649377372716
# Test loss: 0.02388533607881982
#
# Epoch 119
# ---------
# Train loss: 0.0012208445534211464
# Test loss: 0.03785371402045712
#
# Epoch 120
# ---------
# Train loss: 0.0011664539640825692
# Test loss: 0.04454863938735798
#
# Epoch 121
# ---------
# Train loss: 0.0012466883154927692
# Test loss: 0.013530943571822718
#
# Epoch 122
# ---------
# Train loss: 0.0011207229887781245
# Test loss: 0.025936618229025044
#
# Epoch 123
# ---------
# Train loss: 0.001165452875166891
# Test loss: 0.016147805465152487
#
# Epoch 124
# ---------
# Train loss: 0.001135775417130771
# Test loss: 0.010105042485520244
#
# Epoch 125
# ---------
# Train loss: 0.0011540318974443981
# Test loss: 0.013651354689500295
#
# Epoch 126
# ---------
# Train loss: 0.00114815603874083
# Test loss: 0.07180591914220713
#
# Epoch 127
# ---------
# Train loss: 0.0011179595043828276
# Test loss: 0.4744782060588477
#
# Epoch 128
# ---------
# Train loss: 0.0011379322862804628
# Test loss: 0.017760979186277837
#
# Epoch 129
# ---------
# Train loss: 0.0012445734074947635
# Test loss: 0.03748830620315857
#
# Epoch 130
# ---------
# Train loss: 0.0010959532718838854
# Test loss: 0.02704212724347599
#
# Epoch 131
# ---------
# Train loss: 0.00110135742133641
# Test loss: 0.0415774124849122
#
# Epoch 132
# ---------
# Train loss: 0.0010879764747862223
# Test loss: 0.07213397907617036
#
# Epoch 133
# ---------
# Train loss: 0.0011160979836037563
# Test loss: 0.035082122529274784
#
# Epoch 134
# ---------
# Train loss: 0.0012005244343233626
# Test loss: 0.07616842424613424
#
# Epoch 135
# ---------
# Train loss: 0.0011424493293875017
# Test loss: 0.02823521949176211
#
# Epoch 136
# ---------
# Train loss: 0.0011496554838114179
# Test loss: 0.06318587658461183
#
# Epoch 137
# ---------
# Train loss: 0.0010856112435689166
# Test loss: 0.05542760877870023
#
# Epoch 138
# ---------
# Train loss: 0.001121525558705945
# Test loss: 0.3832014739746228
#
# Epoch 139
# ---------
# Train loss: 0.0010810674237643157
# Test loss: 2.996927836778923
#
# Epoch 140
# ---------
# Train loss: 0.001119436988500961
# Test loss: 0.047659508578362875
#
# Epoch 141
# ---------
# Train loss: 0.0011176497885777104
# Test loss: 0.03417567325232085
#
# Epoch 142
# ---------
# Train loss: 0.0010496329904849371
# Test loss: 0.03866198961623013
#
# Epoch 143
# ---------
# Train loss: 0.0011133935418441861
# Test loss: 4.626973675272893
#
# Epoch 144
# ---------
# Train loss: 0.0010697653058506999
# Test loss: 5.628666411183076
#
# Epoch 145
# ---------
# Train loss: 0.0010855822641338642
# Test loss: 0.6438620316475863
#
# Epoch 146
# ---------
# Train loss: 0.0011756988796180175
# Test loss: 3.2394041063962504
#
# Epoch 147
# ---------
# Train loss: 0.0010791460822914697
# Test loss: 3.789170950461994
#
# Epoch 148
# ---------
# Train loss: 0.001054681305944424
# Test loss: 0.032112597618834116
#
# Epoch 149
# ---------
# Train loss: 0.0011057118883341431
# Test loss: 3.4286662678205175
#
# (0.2, 1e-05, 0.001, 512, 1, 64, 3, False, 90, 1, 1, 32)
# Epoch 0
# ---------
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:83: UserWarning:
#
# dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
# Train loss: 0.13455069513574633
# Test loss: 0.7364628672366962
#
# Epoch 1
# ---------
# Train loss: 0.003379128510958605
# Test loss: 0.34429540671408176
#
# Epoch 2
# ---------
# Train loss: 0.003107880605966784
# Test loss: 0.11598219907318708
#
# Epoch 3
# ---------
# Train loss: 0.0026300349230540076
# Test loss: 0.19404630630742759
#
# Epoch 4
# ---------
# Train loss: 0.0031441888582306884
# Test loss: 0.17185570090077817
#
# Epoch 5
# ---------
# Train loss: 0.002520822973888097
# Test loss: 0.1061586607247591
#
# Epoch 6
# ---------
# Train loss: 0.0024652269799374945
# Test loss: 0.08674982539378107
#
# Epoch 7
# ---------
# Train loss: 0.002287367507139401
# Test loss: 0.037317509995773435
#
# Epoch 8
# ---------
# Train loss: 0.0021690207274420365
# Test loss: 0.015832520701223984
#
# Epoch 9
# ---------
# Train loss: 0.002243427618879885
# Test loss: 0.07601374574005604
#
# Epoch 10
# ---------
# Train loss: 0.0020774854436298954
# Test loss: 0.016487003333168104
#
# Epoch 11
# ---------
# Train loss: 0.0020171063867652967
# Test loss: 0.022596770140808076
#
# Epoch 12
# ---------
# Train loss: 0.001987216964593127
# Test loss: 0.029057269624900073
#
# Epoch 13
# ---------
# Train loss: 0.002060215617905581
# Test loss: 0.01831474350183271
#
# Epoch 14
# ---------
# Train loss: 0.001862679291309999
# Test loss: 0.04144516761880368
#
# Epoch 15
# ---------
# Train loss: 0.0017834890876979297
# Test loss: 0.04645015101414174
#
# Epoch 16
# ---------
# Train loss: 0.0017457700946139202
# Test loss: 0.01596554520074278
#
# Epoch 17
# ---------
# Train loss: 0.0016089404380181804
# Test loss: 0.010307633594493382
#
# Epoch 18
# ---------
# Train loss: 0.0016397800357099773
# Test loss: 0.008035354490857571
#
# Epoch 19
# ---------
# Train loss: 0.001589803247395227
# Test loss: 0.008591815480031073
#
# Epoch 20
# ---------
# Train loss: 0.0015316544928693123
# Test loss: 0.01664980928762816
#
# Epoch 21
# ---------
# Train loss: 0.001610437185116743
# Test loss: 0.026103869458893314
#
# Epoch 22
# ---------
# Train loss: 0.0014508220143221889
# Test loss: 0.007746870614937507
#
# Epoch 23
# ---------
# Train loss: 0.0014450250255909087
# Test loss: 0.006207227517734282
#
# Epoch 24
# ---------
# Train loss: 0.0014832852217706762
# Test loss: 0.012869074213085696
#
# Epoch 25
# ---------
# Train loss: 0.0015362578006686582
# Test loss: 0.011191583325853571
#
# Epoch 26
# ---------
# Train loss: 0.0013934241850943035
# Test loss: 0.007162613706896082
#
# Epoch 27
# ---------
# Train loss: 0.001396784227484116
# Test loss: 0.012264903605682775
#
# Epoch 28
# ---------
# Train loss: 0.001440631620249816
# Test loss: 0.010026146686868742
#
# Epoch 29
# ---------
# Train loss: 0.0013392078809932085
# Test loss: 0.006346604292048141
#
# Epoch 30
# ---------
# Train loss: 0.0012339392026572773
# Test loss: 0.01158072627731599
#
# Epoch 31
# ---------
# Train loss: 0.0013745841741535602
# Test loss: 0.026363230892457068
#
# Epoch 32
# ---------
# Train loss: 0.0013955686651658447
# Test loss: 0.008863204770023003
#
# Epoch 33
# ---------
# Train loss: 0.0012501895689638332
# Test loss: 0.0056838458112906665
#
# Epoch 34
# ---------
# Train loss: 0.0013497578176846277
# Test loss: 0.012555184162920341
#
# Epoch 35
# ---------
# Train loss: 0.0012507444391244903
# Test loss: 0.015429317223606631
#
# Epoch 36
# ---------
# Train loss: 0.001599585458837194
# Test loss: 0.027048721443861723
#
# Epoch 37
# ---------
# Train loss: 0.0013423014196075288
# Test loss: 0.005548800007090904
#
# Epoch 38
# ---------
# Train loss: 0.0012580958681346307
# Test loss: 0.005335569170711096
#
# Epoch 39
# ---------
# Train loss: 0.0012331804484288554
# Test loss: 0.005468842544360086
#
# Epoch 40
# ---------
# Train loss: 0.0013100054293904723
# Test loss: 0.013180071488022804
#
# Epoch 41
# ---------
# Train loss: 0.001239795451833596
# Test loss: 0.01738651021150872
#
# Epoch 42
# ---------
# Train loss: 0.0013354909946604993
# Test loss: 0.012885337986517698
#
# Epoch 43
# ---------
# Train loss: 0.0013752959001125888
# Test loss: 0.019234231091104448
#
# Epoch 44
# ---------
# Train loss: 0.0015074995347775608
# Test loss: 0.042963547515682876
#
# Epoch 45
# ---------
# Train loss: 0.0013237025777925737
# Test loss: 0.005228976864600554
#
# Epoch 46
# ---------
# Train loss: 0.0013356387484706037
# Test loss: 0.006142330850707367
#
# Epoch 47
# ---------
# Train loss: 0.0013464571006367014
# Test loss: 0.013104308920446783
#
# Epoch 48
# ---------
# Train loss: 0.0013684642387576582
# Test loss: 0.005859010489075445
#
# Epoch 49
# ---------
# Train loss: 0.0015229556586071398
# Test loss: 0.009389131737407297
#
# Epoch 50
# ---------
# Train loss: 0.0013426862421892433
# Test loss: 0.016614188949461095
#
# Epoch 51
# ---------
# Train loss: 0.0012738619374314084
# Test loss: 0.010126246168510988
#
# Epoch 52
# ---------
# Train loss: 0.0012659086792301687
# Test loss: 0.014924606075510383
#
# Epoch 53
# ---------
# Train loss: 0.0014957594199410278
# Test loss: 0.038474605476949364
#
# Epoch 54
# ---------
# Train loss: 0.0012634387495645864
# Test loss: 0.019706219725776464
#
# Epoch 55
# ---------
# Train loss: 0.001367191600776653
# Test loss: 0.007416533975629136
#
# Epoch 56
# ---------
# Train loss: 0.0012929696613648576
# Test loss: 0.015421351767145097
#
# Epoch 57
# ---------
# Train loss: 0.0012189189088061421
# Test loss: 0.01451948111935053
#
# Epoch 58
# ---------
# Train loss: 0.0012641022626813801
# Test loss: 0.01944329694379121
#
# Epoch 59
# ---------
# Train loss: 0.0013143662116847062
# Test loss: 0.012733528157696128
#
# Epoch 60
# ---------
# Train loss: 0.0013639753888128325
# Test loss: 0.032933782727923244
#
# Epoch 61
# ---------
# Train loss: 0.0013526945854649849
# Test loss: 0.021570216747932136
#
# Epoch 62
# ---------
# Train loss: 0.0013798561739085632
# Test loss: 0.0071911760460352525
#
# Epoch 63
# ---------
# Train loss: 0.0013149468410824006
# Test loss: 0.016980293512460776
#
# Epoch 64
# ---------
# Train loss: 0.0014192368363447098
# Test loss: 0.007377439265837893
#
# Epoch 65
# ---------
# Train loss: 0.001314204383356076
# Test loss: 0.016492441820446402
#
# Epoch 66
# ---------
# Train loss: 0.0012722670558545242
# Test loss: 0.01517198295914568
#
# Epoch 67
# ---------
# Train loss: 0.0012470560085925935
# Test loss: 0.028345295722829178
#
# Epoch 68
# ---------
# Train loss: 0.0012721410845012043
# Test loss: 0.024033229856286198
#
# Epoch 69
# ---------
# Train loss: 0.0013060107099121406
# Test loss: 0.03654931334313005
#
# Epoch 70
# ---------
# Train loss: 0.00139272975878069
# Test loss: 0.04891805234365165
#
# Epoch 71
# ---------
# Train loss: 0.001301073992151707
# Test loss: 0.012061038432875648
#
# Epoch 72
# ---------
# Train loss: 0.0012727469797790682
# Test loss: 0.025090183975407854
#
# Epoch 73
# ---------
# Train loss: 0.0013096162747974777
# Test loss: 0.01728406801703386
#
# Epoch 74
# ---------
# Train loss: 0.0014186790710570471
# Test loss: 0.012319296030909754
#
# Epoch 75
# ---------
# Train loss: 0.0012779486351064406
# Test loss: 0.017998181749135256
#
# Epoch 76
# ---------
# Train loss: 0.0013819507153276654
# Test loss: 0.016483118088217452
#
# Epoch 77
# ---------
# Train loss: 0.0014167037567653273
# Test loss: 0.014972110599046573
#
# Epoch 78
# ---------
# Train loss: 0.0012757050614210688
# Test loss: 0.03722036111867055
#
# Epoch 79
# ---------
# Train loss: 0.0012866054978897614
# Test loss: 0.017338859586743638
#
# Epoch 80
# ---------
# Train loss: 0.0012959825774399383
# Test loss: 0.05844902450917289
#
# Epoch 81
# ---------
# Train loss: 0.0013525636963857969
# Test loss: 0.03454741001769435
#
# Epoch 82
# ---------
# Train loss: 0.0013096939841371722
# Test loss: 0.0090151160111418
#
# Epoch 83
# ---------
# Train loss: 0.001312783209516877
# Test loss: 0.05206756613915786
#
# Epoch 84
# ---------
# Train loss: 0.0013469974848351652
# Test loss: 0.011010508256731555
#
# Epoch 85
# ---------
# Train loss: 0.0013074435552088317
# Test loss: 0.010031736877863295
#
# Epoch 86
# ---------
# Train loss: 0.001184735050511306
# Test loss: 0.02818321502127219
#
# Epoch 87
# ---------
# Train loss: 0.0012560355776992265
# Test loss: 0.022420253255404532
#
# Epoch 88
# ---------
# Train loss: 0.0012723661113282546
# Test loss: 0.010800560907227919
#
# Epoch 89
# ---------
# Train loss: 0.0012635145610528848
# Test loss: 0.022169104413478635
#
# Epoch 90
# ---------
# Train loss: 0.0012478695148714788
# Test loss: 0.014214239534339868
#
# Epoch 91
# ---------
# Train loss: 0.001262380876728604
# Test loss: 0.01228032614744734
#
# Epoch 92
# ---------
# Train loss: 0.0013181410927978914
# Test loss: 0.01812100413371809
#
# Epoch 93
# ---------
# Train loss: 0.0011821243500772624
# Test loss: 0.02336406527319923
#
# Epoch 94
# ---------
# Train loss: 0.0012770491873285914
# Test loss: 0.03459132765419781
#
# Epoch 95
# ---------
# Train loss: 0.001206640041228609
# Test loss: 0.05402976492769085
#
# Epoch 96
# ---------
# Train loss: 0.0012701927670634413
# Test loss: 0.016903187439311296
#
# Epoch 97
# ---------
# Train loss: 0.0012585948493177702
# Test loss: 0.013505007460480556
#
# Epoch 98
# ---------
# Train loss: 0.001192772363860821
# Test loss: 0.023197982693091035
#
# Epoch 99
# ---------
# Train loss: 0.0012807572587212968
# Test loss: 0.03291708100005053
#
# Epoch 100
# ---------
# Train loss: 0.0012690685055736872
# Test loss: 0.025811220286414027
#
# Epoch 101
# ---------
# Train loss: 0.0012696280166217607
# Test loss: 0.030486790783470497
#
# Epoch 102
# ---------
# Train loss: 0.0013475539958416184
# Test loss: 0.04757582483580336
#
# Epoch 103
# ---------
# Train loss: 0.0013022858425580535
# Test loss: 0.01978951063938439
#
# Epoch 104
# ---------
# Train loss: 0.0012582087000473326
# Test loss: 0.012069956253981218
#
# Epoch 105
# ---------
# Train loss: 0.0012323167996533635
# Test loss: 0.009006015461636707
#
# Epoch 106
# ---------
# Train loss: 0.0011551574071129453
# Test loss: 0.05870434199459851
#
# Epoch 107
# ---------
# Train loss: 0.0012690877065911228
# Test loss: 0.013513235899154097
#
# Epoch 108
# ---------
# Train loss: 0.0013601371341088275
# Test loss: 0.030819827690720558
#
# Epoch 109
# ---------
# Train loss: 0.0012707754748032217
# Test loss: 0.011019006589776836
#
# Epoch 110
# ---------
# Train loss: 0.0012564351498205665
# Test loss: 0.04324392441776581
#
# Epoch 111
# ---------
# Train loss: 0.0012308101509153212
# Test loss: 0.015249521238729358
#
# Epoch 112
# ---------
# Train loss: 0.0012832199393033666
# Test loss: 0.008450331864878535
#
# Epoch 113
# ---------
# Train loss: 0.0011954441842164905
# Test loss: 0.01223605174163822
#
# Epoch 114
# ---------
# Train loss: 0.0011811996556653252
# Test loss: 0.01026076426205691
#
# Epoch 115
# ---------
# Train loss: 0.0012432703834718032
# Test loss: 0.009943553232005797
#
# Epoch 116
# ---------
# Train loss: 0.001169288235917432
# Test loss: 0.006720967605360784
#
# Epoch 117
# ---------
# Train loss: 0.0014033848523057155
# Test loss: 0.007431842808728106
#
# Epoch 118
# ---------
# Train loss: 0.0012262535640348365
# Test loss: 0.024478540843119845
#
# Epoch 119
# ---------
# Train loss: 0.0011939077347990186
# Test loss: 0.010205307480646297
#
# Epoch 120
# ---------
# Train loss: 0.00122074716895323
# Test loss: 0.005086276134534273
#
# Epoch 121
# ---------
# Train loss: 0.0012176371164969169
# Test loss: 0.015100129006896168
#
# Epoch 122
# ---------
# Train loss: 0.0012496045960541514
# Test loss: 0.01131643314147368
#
# Epoch 123
# ---------
# Train loss: 0.0011722725462130902
# Test loss: 0.053296386380679905
#
# Epoch 124
# ---------
# Train loss: 0.0012109864675890535
# Test loss: 0.01144474427565001
#
# Epoch 125
# ---------
# Train loss: 0.0012649004901534007
# Test loss: 0.005792215350084007
#
# Epoch 126
# ---------
# Train loss: 0.0011800748156195868
# Test loss: 0.005993799117277376
#
# Epoch 127
# ---------
# Train loss: 0.0012150452267603888
# Test loss: 0.006340715408441611
#
# Epoch 128
# ---------
# Train loss: 0.0011569186685993636
# Test loss: 0.006651406816672534
#
# Epoch 129
# ---------
# Train loss: 0.0011890203668078738
# Test loss: 0.007506499998271465
#
# Epoch 130
# ---------
# Train loss: 0.0011892820588283001
# Test loss: 0.007574273782665841
#
# Epoch 131
# ---------
# Train loss: 0.001176782797800467
# Test loss: 0.005963687784969807
#
# Epoch 132
# ---------
# Train loss: 0.0012308793985510184
# Test loss: 0.006643301006988622
#
# Epoch 133
# ---------
# Train loss: 0.0012838921639711535
# Test loss: 0.026460713823325932
#
# Epoch 134
# ---------
# Train loss: 0.0012228113973246618
# Test loss: 0.01153202798741404
#
# Epoch 135
# ---------
# Train loss: 0.0012127476419986887
# Test loss: 0.007702792077907361
#
# Epoch 136
# ---------
# Train loss: 0.0011821855866489181
# Test loss: 0.008656781647005118
#
# Epoch 137
# ---------
# Train loss: 0.0011312595808938627
# Test loss: 0.012980634666746482
#
# Epoch 138
# ---------
# Train loss: 0.001183548572073285
# Test loss: 0.006328013929305598
#
# Epoch 139
# ---------
# Train loss: 0.0011150539259336169
# Test loss: 0.006284834613325074
#
# Epoch 140
# ---------
# Train loss: 0.0011371109280697701
# Test loss: 0.007256882352521643
#
# Epoch 141
# ---------
# Train loss: 0.0011584062790901835
# Test loss: 0.4291979631234426
#
# Epoch 142
# ---------
# Train loss: 0.0011459037820215248
# Test loss: 0.17280033277347684
#
# Epoch 143
# ---------
# Train loss: 0.001147744665720365
# Test loss: 0.014254567999159917
#
# Epoch 144
# ---------
# Train loss: 0.0011061361189105459
# Test loss: 0.14056637664907612
#
# Epoch 145
# ---------
# Train loss: 0.0011425430258837409
# Test loss: 8.763799877095153
#
# Epoch 146
# ---------
# Train loss: 0.0011001738985801385
# Test loss: 0.009643033554311842
#
# Epoch 147
# ---------
# Train loss: 0.0011234110998855377
# Test loss: 9.119352289708331
#
# Epoch 148
# ---------
# Train loss: 0.0010925548781561966
# Test loss: 1.3737407277221791
#
# Epoch 149
# ---------
# Train loss: 0.0011219588300117457
# Test loss: 0.16085880211903714
#
# Best params: (0.2, 1e-05, 0.001, 256, 1, 64, 3, False, 90, 1, 1, 32)
# Best val loss: 0.004629178089089692
#                            Close_lead1  Model forecast
# Date
# 2022-05-02 00:00:00-04:00  4175.479980     2586.339111
# 2022-05-03 00:00:00-04:00  4300.169922     2619.761230
# 2022-05-04 00:00:00-04:00  4146.870117     2806.587891
# 2022-05-05 00:00:00-04:00  4123.339844     2419.795898
# 2022-05-06 00:00:00-04:00  3991.239990     2675.910156
# ...                                ...             ...
# 2024-05-02 00:00:00-04:00  5127.790039     2443.333740
# 2024-05-03 00:00:00-04:00  5180.740234     2398.638672
# 2024-05-06 00:00:00-04:00  5187.700195     2335.179443
# 2024-05-07 00:00:00-04:00  5187.669922     2275.480957
# 2024-05-08 00:00:00-04:00  5214.080078     2408.344238
#
# [508 rows x 2 columns]
# best_val_loss = 0.004629178089089692
# MSE = 5.858392271945482
# MASE = 4.595687662583593
# RMSE = 1513.1448576231696
# SMAPE = 34.822764289598865
# MAE = 1267.5792387714537
# sharp_ratio = 2.351815905108884
# dropout_lstm: 0.2
# weight_decay: 1e-05
# learning_rate: 0.001
# num_lstm_hiddensize: 256
# lstm_layers: 1
# filters: 64
# kernel_size: 3
# bidirectional: False
# num_consecutive_days: 90
# days_pred: 1
# num_features: 1
# batch_size: 32

# %%
param_grid = copy_from_best(best_params)
param_grid['lstm_layers'] = [1, 3, 5]
param_grid['dropout_lstm'] = [0.0, 0.2]
param_combinations = list(product(*param_grid.values()))
best_params = grid_search(param_combinations)

param_grid = copy_from_best(best_params)
for key, value in param_grid.items():
    print(f"{key}: {value[0]}")
